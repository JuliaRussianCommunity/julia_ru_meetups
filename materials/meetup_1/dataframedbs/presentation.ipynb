# %% [markdown]
# # Строчные и колоночные БД
#
# ## Строчные (традиционные БД)
#     Данные храняться как записанные подряд кортежи строк, часто в одном файле
#     ```
#         ["a", 1, 1.1], ["b", 2, 2.2], ["c", 3, 3.3]
#     ```
#     Плюсы:
#     * Легче реализовать быструю вставку, и изменение записи, транзакционность и т.д.
#     Минусы:
#     * Даже если запрос затрагивает небольшое кол-во колонок, приходится читать с диска все данные
#     * Сложно реализовать векторизацию вычислений
#
# ## Колоночные БД
#     Каждая колонка храниться как отдельный массив, чаще всего в отдельном файле
#     ```
#         ["a", "b", "c"],
#         [1, 2, 3],
#         [1.1, 2.2, 3.3],
#     ```
#     Плюсы:
#     * С диска читаются только колонки действительно нужные для выполнения запроса
#     * Векторизация вычислений практечиски "из коробки"
#     Минусы:
#     * Нужно синхронизировать позицию элементов соответвующих одной строке
#     * Как следствие вставка в произвольную позицию довольно сложная с технической точки зрения операция

# %% [markdown]
# # DataFrameDBs
#
# https://github.com/waralex/DataFrameDBs.jl
#
# Протопип колоночной БД, написанный на Julia.
# Умеет хранить на диске колонки с базовыми типами Julia (все числовые + даты + строки + Union{Missing, T})
#
# Цель написания протопипа прежде всего проверить реализуемость такой БД на Julia и посмотреть на производительность того, что получится
#
# ## Кратко об устройстве
#
# * Таблица DataFrameDBs это папка, в которой есть файл `meta.bin` с метаинформацией таблицы(Названия и порядок следвания колонок) и файлы `<номер колонки>.bin` с данными по отдельным колонкам.
#
# * Заголовок файла колонки таблицы выглядит следующим образом:
# ```
# Тип колонки(Строка)
# Версия формата(Int64)
# Размер блока(в строках)
# ```
#
# * Данные в файлах колонок разбиты на блоки по n значений (определяется при создании таблицы, по умолчанию 65536 (2^16))
#
# * Каждый блок записывается в файл в следующем виде:
# ```
# Кол-во строк в блоке
# Размер данных в блоке в байтах
# Размер данных блока после сжатия их с помощью lz2
# Данные блока, сжатые lz2
# ```
# * Соответвенно все операции над таблицей происходят следующим образом:
#
# Предположим что нам нужно вывести сумму колонок `a` и `b` при условии что `c == 1`
#
#     1. Определим какие колонки нам нужны для запроса - в нашем случае `a`, `b` и `c`
#     2. Создадим в памяти буфферы для этих колонок размером в один блок (т.е. 3 массива в 2^16 элементов каждый)
#     3. Прочитаем с диска и разожмем в буфферы данные 1го блока
#     4. Выполним на буффере нужные нам операции - т.е. найдем для каких строк `c == 1` и добавим в массив результатов `a+b` из этих строк
#     5. Прочитаем с диска в буффер следующий блок и т.д. пока не вычитаем все блоки
#
# В результате с одной стороны вне завивисимости от того, сколько строк в таблице для вычислений необходима память только для хранения 1го блока данных (и результата), с другой стороны т.к. блок достаточно большой на нем работает векторизация вычислений

# %% [markdown]
# ## А теперь как это выглядит с точки зрения пользователя

# %%
using OnlineStats

# %%
using DataFrameDBs

# %%
using Statistics

# %%
using UUIDs

# %%
using Dates

# %%
ENV["COLUMNS"] = 1000;

# %%
DataFrameDBs.ColumnTypes.serialize(::Type{UUID}) = DataFrameDBs.ColumnTypes.Ast(Symbol("UUID"))
DataFrameDBs.ColumnTypes.deserialize(::Val{Symbol("UUID")}) = UUIDs.UUID

# %% [markdown]
# # Табличка ecommerce
#
# Небольшая табличка в 67.5 млн. строк взята отсюда - https://www.kaggle.com/mkechinov/ecommerce-behavior-data-from-multi-category-store и сконвертирована в табличку DataFrameDbs

# %%
table = open_table("ecommerce")
# Out:
# DFTable path: ecommerce
# 10×6 DataFrame
# │ Row │ column        │ type     │ rows       │ uncompressed size │ compressed size │ compression ratio │
# │     │ Symbol        │ String   │ String     │ String            │ String          │ Float64           │
# ├─────┼───────────────┼──────────┼────────────┼───────────────────┼─────────────────┼───────────────────┤
# │ 1   │ event_time    │ DateTime │ 67.5 MRows │ 515.0 MB          │ 22.05 MB        │ 23.36             │
# │ 2   │ event_type    │ String   │ 67.5 MRows │ 518.5 MB          │ 28.03 MB        │ 18.5              │
# │ 3   │ product_id    │ Int64    │ 67.5 MRows │ 515.0 MB          │ 249.36 MB       │ 2.07              │
# │ 4   │ category_id   │ Int64    │ 67.5 MRows │ 515.0 MB          │ 184.1 MB        │ 2.8               │
# │ 5   │ category_code │ String   │ 67.5 MRows │ 1.2 GB            │ 288.77 MB       │ 4.26              │
# │ 6   │ brand         │ String   │ 67.5 MRows │ 588.95 MB         │ 258.98 MB       │ 2.27              │
# │ 7   │ price         │ Float64  │ 67.5 MRows │ 515.0 MB          │ 292.17 MB       │ 1.76              │
# │ 8   │ user_id       │ Int64    │ 67.5 MRows │ 515.0 MB          │ 270.7 MB        │ 1.9               │
# │ 9   │ user_session  │ UUID
#  │ 67.5 MRows │ 1.01 GB           │ 714.7 MB        │ 1.44              │
# │ 10  │ Table total   │          │ 67.5 MRows │ 5.8 GB            │ 2.25 GB         │ 2.57              │

# %%
head(table)
# Out:
# 10×9 DataFrame
# │ Row │ event_time          │ event_type │ product_id │ category_id         │ category_code             │ brand    │ price   │ user_id   │ user_session                                 │
# │     │ DateTime            │ String     │ Int64      │ Int64               │ String                    │ String   │ Float64 │ Int64     │ UUID                                         │
# ├─────┼─────────────────────┼────────────┼────────────┼─────────────────────┼───────────────────────────┼──────────┼─────────┼───────────┼──────────────────────────────────────────────┤
# │ 1   │ 2019-11-01T00:00:00 │ view       │ 1003461    │ 2053013555631882655 │ electronics.smartphone    │ xiaomi   │ 489.07  │ 520088904 │ UUID("4d3b30da-a5e4-49df-b1a8-ba5943f1dd33") │
# │ 2   │ 2019-11-01T00:00:00 │ view       │ 5000088    │ 2053013566100866035 │ appliances.sewing_machine │ janome   │ 293.65  │ 530496790 │ UUID("8e5f4f83-366c-4f70-860e-ca7417414283") │
# │ 3   │ 2019-11-01T00:00:01 │ view       │ 17302664   │ 2053013553853497655 │                           │ creed    │ 28.31   │ 561587266 │ UUID("755422e7-9040-477b-9bd2-6a6e8fd97387") │
# │ 4   │ 2019-11-01T00:00:01 │ view       │ 3601530    │ 2053013563810775923 │ appliances.kitchen.washer │ lg       │ 712.87  │ 518085591 │ UUID("3bfb58cd-7892-48cc-8020-2f17e6de6e7f") │
# │ 5   │ 2019-11-01T00:00:01 │ view       │ 1004775    │ 2053013555631882655 │ electronics.smartphone    │ xiaomi   │ 183.27  │ 558856683 │ UUID("313628f1-68b8-460d-84f6-cec7a8796ef2") │
# │ 6   │ 2019-11-01T00:00:01 │ view       │ 1306894    │ 2053013558920217191 │ computers.notebook        │ hp       │ 360.09  │ 520772685 │ UUID("816a59f3-f5ae-4ccd-9b23-82aa8c23d33c") │
# │ 7   │ 2019-11-01T00:00:01 │ view       │ 1306421    │ 2053013558920217191 │ computers.notebook        │ hp       │ 514.56  │ 514028527 │ UUID("df8184cc-3694-4549-8c8c-6b5171877376") │
# │ 8   │ 2019-11-01T00:00:02 │ view       │ 15900065   │ 2053013558190408249 │                           │ rondell  │ 30.86   │ 518574284 │ UUID("5e6ef132-4d7c-4730-8c7f-85aa4082588f") │
# │ 9   │ 2019-11-01T00:00:02 │ view       │ 12708937   │ 2053013553559896355 │                           │ michelin │ 72.72   │ 532364121 │ UUID("0a899268-31eb-46de-898d-09b2da950b24") │
# │ 10  │ 2019-11-01T00:00:02 │ view       │ 1004258    │ 2053013555631882655 │ electronics.smartphone    │ apple    │ 732.07  │ 532647354 │ UUID("d2d3d2c6-631d-489e-9fb5-06f340b85be0") │

# %% [markdown]
# * включим отоброжение прогресса выполенния запросов

# %%
turnon_progress!(table);

# %% [markdown]
# ## DFColumn - lazy колонка - итератор к данным, лежащим на диске

# %%
table.event_type
# Out:
# DFColumn{String}

# %%
length(table.event_type)
# Out:
# Time: 0:00:0.2924 read: 67.5 MRows (230.89 MRows/sec))
# 67501979

# %%
unique(table.event_type)
# Out:
# Time: 0:00:20.6292 read: 67.5 MRows (3.27 MRows/sec))0:00:1.1076 read: 2.82 MRows (2.54 MRows/sec)0:00:1.8820 read: 5.51 MRows (2.93 MRows/sec)0:00:2.6472 read: 8.06 MRows (3.05 MRows/sec)0:00:3.3064 read: 10.22 MRows (3.09 MRows/sec)0:00:4.0617 read: 12.78 MRows (3.15 MRows/sec)0:00:4.8561 read: 15.47 MRows (3.18 MRows/sec)0:00:5.7405 read: 18.48 MRows (3.22 MRows/sec)0:00:6.3943 read: 20.71 MRows (3.24 MRows/sec)0:00:7.8258 read: 25.62 MRows (3.27 MRows/sec)0:00:8.6028 read: 28.31 MRows (3.29 MRows/sec)0:00:9.2655 read: 30.54 MRows (3.3 MRows/sec)0:00:10.6924 read: 35.45 MRows (3.32 MRows/sec)0:00:12.2716 read: 40.63 MRows (3.31 MRows/sec)0:00:13.0762 read: 43.32 MRows (3.31 MRows/sec)0:00:13.8365 read: 45.81 MRows (3.31 MRows/sec)0:00:14.5108 read: 48.04 MRows (3.31 MRows/sec)0:00:15.0685 read: 49.74 MRows (3.3 MRows/sec)0:00:15.8461 read: 52.36 MRows (3.3 MRows/sec)0:00:17.1952 read: 56.82 MRows (3.3 MRows/sec)0:00:17.8386 read: 58.79 MRows (3.3 MRows/sec)0:00:18.3793 read: 60.49 MRows (3.29 MRows/sec)0:00:19.8410 read: 65.14 MRows (3.28 MRows/sec)0:00:20.3976 read: 66.85 MRows (3.28 MRows/sec)
# 3-element Vector{String}:
#  "view"
#  "cart"
#  "purchase"

# %% [markdown]
# ### Индексация DFColumn - это тоже DFColumn. Индексация применяется так же в lazy режиме при материалицазии колонки

# %%
ev_10 = table.event_type[1:100:30_000_000]
# Out:
# DFColumn{String}

# %%
size(ev_10)
# Out:
# Time: 0:00:0.7207 read: 30.02 MRows (41.65 MRows/sec)
# (300000,)

# %%
ev_10[1:10]
# Out:
# DFColumn{String}

# %%
materialize(ev_10[1:10])
# Out:
# Time: 0:00:0.0002 read: 65.54 KRows (271.86 MRows/sec)
# 10-element Vector{String}:
#  "view"
#  "view"
#  "view"
#  "view"
#  "view"
#  "view"
#  "view"
#  "view"
#  "view"
#  "view"

# %% [markdown]
# ### Любые  broadcast операции над DFColumn - тоже DFColumn. Операции так же выполняются в lazy режиме

# %%
purchase_condition = table.event_type .== "purchase"
# Out:
# DFColumn{Bool}

# %%
count(purchase_condition)
# Out:
# Time: 0:00:12.5987 read: 67.5 MRows (5.36 MRows/sec))0:00:0.7141 read: 3.87 MRows (5.41 MRows/sec)0:00:1.4631 read: 8.13 MRows (5.55 MRows/sec)0:00:3.0360 read: 17.17 MRows (5.66 MRows/sec)0:00:3.7761 read: 21.43 MRows (5.68 MRows/sec)0:00:5.3482 read: 29.95 MRows (5.6 MRows/sec)0:00:6.1821 read: 34.34 MRows (5.55 MRows/sec)0:00:6.9063 read: 38.27 MRows (5.54 MRows/sec)0:00:8.8308 read: 48.23 MRows (5.46 MRows/sec)0:00:10.0261 read: 54.33 MRows (5.42 MRows/sec)0:00:11.1034 read: 59.83 MRows (5.39 MRows/sec)
# 916939

# %%
tmp = table.price .* 2 ./ table.user_id
# Out:
# DFColumn{Float64}

# %%
materialize(tmp[1:5])
# Out:
# Time: 0:00:0.0004 read: 65.54 KRows (147.26 MRows/sec)
# 5-element Vector{Float64}:
#  1.8807169168138991e-6
#  1.1070755018140636e-6
#  1.0082137439348562e-7
#  2.751939109613261e-6
#  6.558747728172019e-7

# %%
f(brand, price) = brand == "xiaomi" ? price * 1.2 : price * 0.8

new_price = f.(table.brand, table.price)
# Out:
# DFColumn{Float64}

# %%
materialize(new_price[1:10])
# Out:
# Time: 0:00:0.0003 read: 65.54 KRows (253.46 MRows/sec)
# 10-element Vector{Float64}:
#  586.884
#  234.92
#   22.648
#  570.296
#  219.924
#  288.072
#  411.64799999999997
#   24.688000000000002
#   58.176
#  585.6560000000001

# %% [markdown]
# ### DFColumn{Bool} может использоваться для индексации колонки

# %%
purchase_prices = table.price[table.event_type .== "purchase"]
# Out:
# DFColumn{Float64}

# %%
length(purchase_prices)
# Out:
# Time: 0:00:3.5548 read: 67.5 MRows (18.99 MRows/sec))0:00:2.5408 read: 48.43 MRows (19.06 MRows/sec)
# 916939

# %%
mean(purchase_prices)
# Out:
# Time: 0:00:4.9554 read: 67.5 MRows (13.62 MRows/sec))0:00:3.3655 read: 47.05 MRows (13.98 MRows/sec)
# 300.12344387126365

# %% [markdown]
# ## DFView - вью таблицы.
#
# Задается правилами `selection` (фильтрация и/или индексация) и `projection` - набор колонок, которые входят во вьюху
# Так же как и DFColumn реальное чтение данных и выполнение вычислений происходит в момент материализации DFView
# Синтаксис работы с DFView максимально приближен к синтаксису DataFrame

# %% [markdown]
# ### DFView полной таблицы

# %%
full_view = table[:,:]
# Out:
# View of table ecommerce
# Projection: event_time=>col(event_time)::DateTime; event_type=>col(event_type)::String; product_id=>col(product_id)::Int64; category_id=>col(category_id)::Int64; category_code=>col(category_code)::String; brand=>col(brand)::String; price=>col(price)::Float64; user_id=>col(user_id)::Int64; user_session=>col(user_session)::UUID
# Selection:

# %%
full_view.selection

# %%
head(full_view)
# Out:
# Time: 0:00:0.0003 read: 65.54 KRows (228.96 MRows/sec)
# Time: 0:00:0.0005 read: 65.54 KRows (122.02 MRows/sec)
# 10×9 DataFrame
# │ Row │ event_time          │ event_type │ product_id │ category_id         │ category_code             │ brand    │ price   │ user_id   │ user_session                                 │
# │     │ DateTime            │ String     │ Int64      │ Int64               │ String                    │ String   │ Float64 │ Int64     │ UUID                                         │
# ├─────┼─────────────────────┼────────────┼────────────┼─────────────────────┼───────────────────────────┼──────────┼─────────┼───────────┼──────────────────────────────────────────────┤
# │ 1   │ 2019-11-01T00:00:00 │ view       │ 1003461    │ 2053013555631882655 │ electronics.smartphone    │ xiaomi   │ 489.07  │ 520088904 │ UUID("4d3b30da-a5e4-49df-b1a8-ba5943f1dd33") │
# │ 2   │ 2019-11-01T00:00:00 │ view       │ 5000088    │ 2053013566100866035 │ appliances.sewing_machine │ janome   │ 293.65  │ 530496790 │ UUID("8e5f4f83-366c-4f70-860e-ca7417414283") │
# │ 3   │ 2019-11-01T00:00:01 │ view       │ 17302664   │ 2053013553853497655 │                           │ creed    │ 28.31   │ 561587266 │ UUID("755422e7-9040-477b-9bd2-6a6e8fd97387") │
# │ 4   │ 2019-11-01T00:00:01 │ view       │ 3601530    │ 2053013563810775923 │ appliances.kitchen.washer │ lg       │ 712.87  │ 518085591 │ UUID("3bfb58cd-7892-48cc-8020-2f17e6de6e7f") │
# │ 5   │ 2019-11-01T00:00:01 │ view       │ 1004775    │ 2053013555631882655 │ electronics.smartphone    │ xiaomi   │ 183.27  │ 558856683 │ UUID("313628f1-68b8-460d-84f6-cec7a8796ef2") │
# │ 6   │ 2019-11-01T00:00:01 │ view       │ 1306894    │ 2053013558920217191 │ computers.notebook        │ hp       │ 360.09  │ 520772685 │ UUID("816a59f3-f5ae-4ccd-9b23-82aa8c23d33c") │
# │ 7   │ 2019-11-01T00:00:01 │ view       │ 1306421    │ 2053013558920217191 │ computers.notebook        │ hp       │ 514.56  │ 514028527 │ UUID("df8184cc-3694-4549-8c8c-6b5171877376") │
# │ 8   │ 2019-11-01T00:00:02 │ view       │ 15900065   │ 2053013558190408249 │                           │ rondell  │ 30.86   │ 518574284 │ UUID("5e6ef132-4d7c-4730-8c7f-85aa4082588f") │
# │ 9   │ 2019-11-01T00:00:02 │ view       │ 12708937   │ 2053013553559896355 │                           │ michelin │ 72.72   │ 532364121 │ UUID("0a899268-31eb-46de-898d-09b2da950b24") │
# │ 10  │ 2019-11-01T00:00:02 │ view       │ 1004258    │ 2053013555631882655 │ electronics.smartphone    │ apple    │ 732.07  │ 532647354 │ UUID("d2d3d2c6-631d-489e-9fb5-06f340b85be0") │

# %% [markdown]
# ### DFView с фильтрацией и отбором колонок

# %%
purchases = table[table.event_type .== "purchase", [:price, :user_id, :product_id, :brand]]
# Out:
# View of table ecommerce
# Projection: price=>col(price)::Float64; user_id=>col(user_id)::Int64; product_id=>col(product_id)::Int64; brand=>col(brand)::String
# Selection: ==(col(event_type)::String, Base.RefValue{String}("purchase"))::Bool

# %%
purchases.selection

# %%
size(purchases)
# Out:
# Time: 0:00:3.6607 read: 67.5 MRows (18.44 MRows/sec))
# (916939, 4)

# %%
expensive_purchases = purchases[purchases.price .>= 2000, :]
# Out:
# View of table ecommerce
# Projection: price=>col(price)::Float64; user_id=>col(user_id)::Int64; product_id=>col(product_id)::Int64; brand=>col(brand)::String
# Selection: &(==(col(event_type)::String, Base.RefValue{String}("purchase"))::Bool, >=(col(price)::Float64, 2000)::Bool)::Bool

# %%
size(expensive_purchases)
# Out:
# Time: 0:00:5.9688 read: 67.5 MRows (11.31 MRows/sec))0:00:1.6348 read: 18.15 MRows (11.1 MRows/sec)0:00:4.2953 read: 47.97 MRows (11.17 MRows/sec)0:00:5.6380 read: 63.7 MRows (11.3 MRows/sec)
# (1459, 4)

# %% [markdown]
# ### Схлопывание условий в selection

# %%
println(expensive_purchases.selection)
expensive_purchases2 = purchases[1:1000, :][purchases[1:1000, :].price .>= 2000, :]
println(expensive_purchases2.selection)
println(expensive_purchases2[1:100, :].selection)
println(expensive_purchases2[1:100:100000, :][1:5, :].selection)
# Out:
# Selection: &(==(col(event_type)::String, Base.RefValue{String}("purchase"))::Bool, >=(col(price)::Float64, 2000)::Bool)::Bool
# Selection: ==(col(event_type)::String, Base.RefValue{String}("purchase"))::Bool |> 1:1000 |> >=(col(price)::Float64, 2000)::Bool
# Selection: ==(col(event_type)::String, Base.RefValue{String}("purchase"))::Bool |> 1:1000 |> >=(col(price)::Float64, 2000)::Bool |> 1:100
# Selection: ==(col(event_type)::String, Base.RefValue{String}("purchase"))::Bool |> 1:1000 |> >=(col(price)::Float64, 2000)::Bool |> 1:100:401

# %% [markdown]
# ### Проиводные колонки

# %%
convert_price(brand, price) = brand == "xiaomi" ? price * 1.2 : price * 0.8
# Out:
# convert_price (generic function with 1 method)

# %%
[
        :brand => :brand,
        
    ]

# %%
price_changes_table = table[:,
    (
        brand = :brand,
        old_price = :price,
        new_price = (:brand, :price) => convert_price        
        
    )
]
# Out:
# View of table ecommerce
# Projection: brand=>col(brand)::String; old_price=>col(price)::Float64; new_price=>convert_price(col(brand)::String, col(price)::Float64)::Float64
# Selection:

# %%
head(price_changes_table)
# Out:
# Time: 0:00:0.0013 read: 65.54 KRows (52.17 MRows/sec)
# Time: 0:00:0.0957 read: 65.54 KRows (684.47 KRows/sec)
# 10×3 DataFrame
# │ Row │ brand    │ old_price │ new_price │
# │     │ String   │ Float64   │ Float64   │
# ├─────┼──────────┼───────────┼───────────┤
# │ 1   │ xiaomi   │ 489.07    │ 586.884   │
# │ 2   │ janome   │ 293.65    │ 234.92    │
# │ 3   │ creed    │ 28.31     │ 22.648    │
# │ 4   │ lg       │ 712.87    │ 570.296   │
# │ 5   │ xiaomi   │ 183.27    │ 219.924   │
# │ 6   │ hp       │ 360.09    │ 288.072   │
# │ 7   │ hp       │ 514.56    │ 411.648   │
# │ 8   │ rondell  │ 30.86     │ 24.688    │
# │ 9   │ michelin │ 72.72     │ 58.176    │
# │ 10  │ apple    │ 732.07    │ 585.656   │

# %%
price_changes_table = price_changes_table[:,
    (
        brand = :brand,
        old_price = :old_price,
        new_price = :new_price,
        price_change = (:old_price, :new_price) => (o, n) -> n - o        
        
    )
]
# Out:
# View of table ecommerce
# Projection: brand=>col(brand)::String; old_price=>col(price)::Float64; new_price=>convert_price(col(brand)::String, col(price)::Float64)::Float64; price_change=>#1(col(price)::Float64, convert_price(col(brand)::String, col(price)::Float64)::Float64)::Float64
# Selection:

# %%
head(price_changes_table)
# Out:
# Time: 0:00:0.0003 read: 65.54 KRows (208.85 MRows/sec)
# Time: 0:00:0.0473 read: 65.54 KRows (1.39 MRows/sec)
# 10×4 DataFrame
# │ Row │ brand    │ old_price │ new_price │ price_change │
# │     │ String   │ Float64   │ Float64   │ Float64      │
# ├─────┼──────────┼───────────┼───────────┼──────────────┤
# │ 1   │ xiaomi   │ 489.07    │ 586.884   │ 97.814       │
# │ 2   │ janome   │ 293.65    │ 234.92    │ -58.73       │
# │ 3   │ creed    │ 28.31     │ 22.648    │ -5.662       │
# │ 4   │ lg       │ 712.87    │ 570.296   │ -142.574     │
# │ 5   │ xiaomi   │ 183.27    │ 219.924   │ 36.654       │
# │ 6   │ hp       │ 360.09    │ 288.072   │ -72.018      │
# │ 7   │ hp       │ 514.56    │ 411.648   │ -102.912     │
# │ 8   │ rondell  │ 30.86     │ 24.688    │ -6.172       │
# │ 9   │ michelin │ 72.72     │ 58.176    │ -14.544      │
# │ 10  │ apple    │ 732.07    │ 585.656   │ -146.414     │

# %%
sum(price_changes_table.price_change)
# Out:
# Time: 0:00:21.4617 read: 67.5 MRows (3.15 MRows/sec))0:00:0.6343 read: 1.9 MRows (3.0 MRows/sec)0:00:1.1485 read: 3.54 MRows (3.08 MRows/sec)0:00:1.8146 read: 5.44 MRows (3.0 MRows/sec)0:00:2.4726 read: 7.34 MRows (2.97 MRows/sec)0:00:3.1162 read: 9.24 MRows (2.97 MRows/sec)0:00:3.7383 read: 11.14 MRows (2.98 MRows/sec)0:00:4.3709 read: 13.11 MRows (3.0 MRows/sec)0:00:5.0042 read: 15.07 MRows (3.01 MRows/sec)0:00:5.6389 read: 17.04 MRows (3.02 MRows/sec)0:00:6.2707 read: 19.01 MRows (3.03 MRows/sec)0:00:6.8007 read: 20.64 MRows (3.04 MRows/sec)0:00:7.3365 read: 22.28 MRows (3.04 MRows/sec)0:00:7.8556 read: 23.92 MRows (3.05 MRows/sec)0:00:8.5025 read: 25.89 MRows (3.04 MRows/sec)0:00:9.0399 read: 27.53 MRows (3.04 MRows/sec)0:00:9.6695 read: 29.49 MRows (3.05 MRows/sec)0:00:10.3060 read: 31.46 MRows (3.05 MRows/sec)0:00:10.9523 read: 33.42 MRows (3.05 MRows/sec)0:00:11.4724 read: 35.06 MRows (3.06 MRows/sec)0:00:12.1502 read: 37.22 MRows (3.06 MRows/sec)0:00:12.9301 read: 39.78 MRows (3.08 MRows/sec)0:00:13.5907 read: 41.81 MRows (3.08 MRows/sec)0:00:14.2624 read: 43.97 MRows (3.08 MRows/sec)0:00:14.8069 read: 45.68 MRows (3.08 MRows/sec)0:00:15.4773 read: 47.84 MRows (3.09 MRows/sec)0:00:16.3717 read: 50.92 MRows (3.11 MRows/sec)0:00:17.7200 read: 55.31 MRows (3.12 MRows/sec)0:00:18.2481 read: 56.89 MRows (3.12 MRows/sec)0:00:19.3012 read: 60.23 MRows (3.12 MRows/sec)0:00:20.2136 read: 63.37 MRows (3.14 MRows/sec)65.93 MRows (3.14 MRows/sec)
# -3.5703025117562428e9

# %% [markdown]
# ## Аггрегация
#
# Пока только с помощью OnlineStats что не очень эффективно, но работает

# %%
fit!(GroupBy(String, Series(Mean(), Extrema())), zip(purchases.brand, purchases.price))
# Out:
# Time: 0:00:11.0807 read: 67.5 MRows (6.09 MRows/sec)d:  (66.98 MRows6.1 MRows/sec ()6.1 MRows/sec)))22m) read: 0:00:2.371913.11 MRows read:  (13.11 MRows5.5 MRows/sec ()5.53 MRows/sec) read: 0:00:3.185418.15 MRows read:  (18.15 MRows5.68 MRows/sec ()5.7 MRows/sec) read: 0:00:4.203624.64 MRows read:  (24.64 MRows5.85 MRows/sec ()5.86 MRows/sec) read: 0:00:7.555447.19 MRows read:  (47.19 MRows6.24 MRows/sec ()6.25 MRows/sec)
# GroupBy: String => Series
# ├─ ""
# │  └─ Series
# │     ├─ Mean: n=73273 | value=150.475
# │     └─ Extrema: n=73273 | value=(min = 0.79, max = 2574.07, nmin = 3, nmax = 7)
# ├─ "xiaomi"
# │  └─ Series
# │     ├─ Mean: n=68292 | value=164.878
# │     └─ Extrema: n=68292 | value=(min = 1.29, max = 2033.51, nmin = 2, nmax = 1)
# ├─ "samsung"
# │  └─ Series
# │     ├─ Mean: n=200027 | value=274.312
# │     └─ Extrema: n=200027 | value=(min = 1.26, max = 2574.04, nmin = 23, nmax = 6)
# ├─ "lucente"
# │  └─ Series
# │     ├─ Mean: n=14559 | value=242.293
# │     └─ Extrema: n=14559 | value=(min = 11.33, max = 971.97, nmin = 1, nmax = 48)
# ├─ "nakamichi"
# │  └─ Series
# │     ├─ Mean: n=81 | value=83.7544
# │     └─ Extrema: n=81 | value=(min = 28.83, max = 123.56, nmin = 1, nmax = 13)
# ├─ "magnetta"
# │  └─ Series
# │     ├─ Mean: n=250 | value=239.141
# │     └─ Extrema: n=250 | value=(min = 20.59, max = 782.39, nmin = 1, nmax = 1)
# ├─ "cortland"
# │  └─ Series
# │     ├─ Mean: n=190 | value=98.1393
# │     └─ Extrema: n=190 | value=(min = 73.18, max = 154.42, nmin = 7, nmax = 4)
# ├─ "apple"
# │  └─ Series
# │     ├─ Mean: n=166064 | value=767.852
# │     └─ Extrema: n=166064 | value=(min = 4.61, max = 2574.04, nmin = 8, nmax = 15)
# ├─ "maxxis"
# │  └─ Series
# │     ├─ Mean: n=1575 | value=73.8746
# │     └─ Extrema: n=1575 | value=(min = 37.45, max = 179.67, nmin = 9, nmax = 1)
# ├─ "netechnics"
# │  └─ Series
# │     ├─ Mean: n=67 | value=821.869
# │     └─ Extrema: n=67 | value=(min = 553.4, max = 1093.95, nmin = 4, nmax = 6)
# ├─ "sony"
# │  └─ Series
# │     ├─ Mean: n=10309 | value=374.71
# │     └─ Extrema: n=10309 | value=(min = 5.12, max = 2574.04, nmin = 6, nmax = 3)
# ├─ "carfashion"
# │  └─ Series
# │     ├─ Mean: n=331 | value=74.2826
# │     └─ Extrema: n=331 | value=(min = 9.14, max = 144.15, nmin = 1, nmax = 3)
# ├─ "midea"
# │  └─ Series
# │     ├─ Mean: n=4004 | value=156.553
# │     └─ Extrema: n=4004 | value=(min = 14.13, max = 1456.67, nmin = 5, nmax = 1)
# ├─ "hp"
# │  └─ Series
# │     ├─ Mean: n=4106 | value=326.728
# │     └─ Extrema: n=4106 | value=(min = 7.7, max = 2493.02, nmin = 4, nmax = 1)
# ├─ "pulser"
# │  └─ Series
# │     ├─ Mean: n=566 | value=702.104
# │     └─ Extrema: n=566 | value=(min = 182.73, max = 1763.21, nmin = 2, nmax = 1)
# ├─ "hyundai"
# │  └─ Series
# │     ├─ Mean: n=203 | value=91.1983
# │     └─ Extrema: n=203 | value=(min = 12.64, max = 952.41, nmin = 4, nmax = 1)
# ├─ "sv"
# │  └─ Series
# │     ├─ Mean: n=1397 | value=246.985
# │     └─ Extrema: n=1397 | value=(min = 25.74, max = 1096.81, nmin = 5, nmax = 1)
# ├─ "triangle"
# │  └─ Series
# │     ├─ Mean: n=4741 | value=49.6736
# │     └─ Extrema: n=4741 | value=(min = 28.31, max = 319.18, nmin = 3, nmax = 1)
# ├─ "arg"
# │  └─ Series
# │     ├─ Mean: n=2336 | value=113.398
# │     └─ Extrema: n=2336 | value=(min = 25.71, max = 386.08, nmin = 18, nmax = 19)
# ├─ "bosch"
# │  └─ Series
# │     ├─ Mean: n=8010 | value=228.804
# │     └─ Extrema: n=8010 | value=(min = 4.76, max = 1490.09, nmin = 1, nmax = 1)
# ├─ "jbl"
# │  └─ Series
# │     ├─ Mean: n=2630 | value=67.1686
# │     └─ Extrema: n=2630 | value=(min = 7.7, max = 591.78, nmin = 54, nmax = 5)
# ├─ "puma"
# │  └─ Series
# │     ├─ Mean: n=91 | value=94.8456
# │     └─ Extrema: n=91 | value=(min = 44.51, max = 126.1, nmin = 6, nmax = 2)
# ├─ "montblanc"
# │  └─ Series
# │     ├─ Mean: n=167 | value=46.9353
# │     └─ Extrema: n=167 | value=(min = 28.17, max = 196.92, nmin = 2, nmax = 1)
# ├─ "tefal"
# │  └─ Series
# │     ├─ Mean: n=4178 | value=113.094
# │     └─ Extrema: n=4178 | value=(min = 7.95, max = 669.23, nmin = 5, nmax = 4)
# ├─ "casio"
# │  └─ Series
# │     ├─ Mean: n=3523 | value=88.9358
# │     └─ Extrema: n=3523 | value=(min = 15.7, max = 1493.99, nmin = 31, nmax = 1)
# ├─ "oppo"
# │  └─ Series
# │     ├─ Mean: n=15080 | value=231.336
# │     └─ Extrema: n=15080 | value=(min = 128.45, max = 900.9, nmin = 187, nmax = 50)
# ├─ "peak"
# │  └─ Series
# │     ├─ Mean: n=7 | value=112.699
# │     └─ Extrema: n=7 | value=(min = 82.34, max = 123.56, nmin = 1, nmax = 4)
# ├─ "asics"
# │  └─ Series
# │     ├─ Mean: n=42 | value=81.2519
# │     └─ Extrema: n=42 | value=(min = 34.49, max = 173.75, nmin = 1, nmax = 2)
# ├─ "braun"
# │  └─ Series
# │     ├─ Mean: n=2491 | value=96.0579
# │     └─ Extrema: n=2491 | value=(min = 7.72, max = 471.03, nmin = 4, nmax = 4)
# ├─ "cordiant"
# │  └─ Series
# │     ├─ Mean: n=16983 | value=46.3599
# │     └─ Extrema: n=16983 | value=(min = 26.51, max = 448.37, nmin = 21, nmax = 2)
# ├─ "viatti"
# │  └─ Series
# │     ├─ Mean: n=5578 | value=44.0957
# │     └─ Extrema: n=5578 | value=(min = 32.05, max = 132.56, nmin = 1, nmax = 2)
# ├─ "greta"
# │  └─ Series
# │     ├─ Mean: n=41 | value=155.216
# │     └─ Extrema: n=41 | value=(min = 29.16, max = 233.85, nmin = 1, nmax = 1)
# ├─ "hifly"
# │  └─ Series
# │     ├─ Mean: n=400 | value=52.9631
# │     └─ Extrema: n=400 | value=(min = 30.89, max = 136.17, nmin = 14, nmax = 1)
# ├─ "meizu"
# │  └─ Series
# │     ├─ Mean: n=2147 | value=126.602
# │     └─ Extrema: n=2147 | value=(min = 4.86, max = 408.71, nmin = 3, nmax = 2)
# ├─ "huawei"
# │  └─ Series
# │     ├─ Mean: n=23703 | value=201.691
# │     └─ Extrema: n=23703 | value=(min = 4.09, max = 965.02, nmin = 2, nmax = 3)
# ├─ "dsquared"
# │  └─ Series
# │     ├─ Mean: n=4 | value=222.53
# │     └─ Extrema: n=4 | value=(min = 186.62, max = 234.5, nmin = 1, nmax = 3)
# ├─ "stendmebel"
# │  └─ Series
# │     ├─ Mean: n=153 | value=169.856
# │     └─ Extrema: n=153 | value=(min = 57.63, max = 468.97, nmin = 1, nmax = 2)
# ├─ "nokian"
# │  └─ Series
# │     ├─ Mean: n=5981 | value=73.3917
# │     └─ Extrema: n=5981 | value=(min = 35.26, max = 363.72, nmin = 1, nmax = 4)
# ├─ "elari"
# │  └─ Series
# │     ├─ Mean: n=765 | value=55.6367
# │     └─ Extrema: n=765 | value=(min = 14.05, max = 100.23, nmin = 2, nmax = 1)
# ├─ "redmond"
# │  └─ Series
# │     ├─ Mean: n=5120 | value=70.4891
# │     └─ Extrema: n=5120 | value=(min = 10.27, max = 535.38, nmin = 1, nmax = 1)
# ├─ "stels"
# │  └─ Series
# │     ├─ Mean: n=2768 | value=97.579
# │     └─ Extrema: n=2768 | value=(min = 10.27, max = 293.7, nmin = 1, nmax = 1)
# ├─ "tuka"
# │  └─ Series
# │     ├─ Mean: n=48 | value=21.961
# │     └─ Extrema: n=48 | value=(min = 16.73, max = 36.04, nmin = 23, nmax = 7)
# ├─ "gefest"
# │  └─ Series
# │     ├─ Mean: n=733 | value=192.216
# │     └─ Extrema: n=733 | value=(min = 11.58, max = 577.36, nmin = 2, nmax = 1)
# ├─ "scarlett"
# │  └─ Series
# │     ├─ Mean: n=1690 | value=34.8057
# │     └─ Extrema: n=1690 | value=(min = 6.18, max = 187.88, nmin = 1, nmax = 1)
# ├─ "chanel"
# │  └─ Series
# │     ├─ Mean: n=436 | value=162.653
# │     └─ Extrema: n=436 | value=(min = 114.24, max = 261.61, nmin = 8, nmax = 3)
# ├─ "asel"
# │  └─ Series
# │     ├─ Mean: n=958 | value=51.7471
# │     └─ Extrema: n=958 | value=(min = 42.42, max = 99.61, nmin = 13, nmax = 1)
# ├─ "asrock"
# │  └─ Series
# │     ├─ Mean: n=173 | value=138.746
# │     └─ Extrema: n=173 | value=(min = 48.65, max = 919.2, nmin = 2, nmax = 1)
# ├─ "ariston"
# │  └─ Series
# │     ├─ Mean: n=1942 | value=124.567
# │     └─ Extrema: n=1942 | value=(min = 69.48, max = 1467.22, nmin = 10, nmax = 1)
# ├─ "haier"
# │  └─ Series
# │     ├─ Mean: n=3847 | value=288.752
# │     └─ Extrema: n=3847 | value=(min = 38.59, max = 1801.82, nmin = 1, nmax = 1)
# ├─ "arnica"
# │  └─ Series
# │     ├─ Mean: n=250 | value=151.341
# │     └─ Extrema: n=250 | value=(min = 34.49, max = 231.51, nmin = 1, nmax = 1)
# ├─ "indesit"
# │  └─ Series
# │     ├─ Mean: n=5187 | value=251.964
# │     └─ Extrema: n=5187 | value=(min = 16.19, max = 595.1, nmin = 1, nmax = 1)
# ├─ "stayer"
# │  └─ Series
# │     ├─ Mean: n=60 | value=31.0852
# │     └─ Extrema: n=60 | value=(min = 7.21, max = 48.39, nmin = 1, nmax = 1)
# ├─ "philips"
# │  └─ Series
# │     ├─ Mean: n=5539 | value=118.919
# │     └─ Extrema: n=5539 | value=(min = 3.84, max = 1698.81, nmin = 2, nmax = 3)
# ├─ "force"
# │  └─ Series
# │     ├─ Mean: n=1462 | value=151.965
# │     └─ Extrema: n=1462 | value=(min = 27.03, max = 270.28, nmin = 1, nmax = 67)
# ├─ "decoroom"
# │  └─ Series
# │     ├─ Mean: n=166 | value=29.542
# │     └─ Extrema: n=166 | value=(min = 15.01, max = 47.16, nmin = 3, nmax = 1)
# ├─ "hotpoint-ariston"
# │  └─ Series
# │     ├─ Mean: n=154 | value=320.742
# │     └─ Extrema: n=154 | value=(min = 66.64, max = 902.2, nmin = 1, nmax = 2)
# ├─ "moschino"
# │  └─ Series
# │     ├─ Mean: n=406 | value=44.5225
# │     └─ Extrema: n=406 | value=(min = 22.74, max = 162.17, nmin = 3, nmax = 1)
# ├─ "artel"
# │  └─ Series
# │     ├─ Mean: n=9267 | value=177.211
# │     └─ Extrema: n=9267 | value=(min = 17.86, max = 1714.07, nmin = 1, nmax = 14)
# ├─ "lg"
# │  └─ Series
# │     ├─ Mean: n=12879 | value=406.788
# │     └─ Extrema: n=12879 | value=(min = 10.27, max = 2574.04, nmin = 1, nmax = 1)
# ├─ "acer"
# │  └─ Series
# │     ├─ Mean: n=6402 | value=522.853
# │     └─ Extrema: n=6402 | value=(min = 12.07, max = 2574.04, nmin = 3, nmax = 3)
# ├─ "adile"
# │  └─ Series
# │     ├─ Mean: n=35 | value=66.93
# │     └─ Extrema: n=35 | value=(min = 66.93, max = 66.93, nmin = 35, nmax = 35)
# ├─ "galaxy"
# │  └─ Series
# │     ├─ Mean: n=681 | value=28.7786
# │     └─ Extrema: n=681 | value=(min = 3.35, max = 85.54, nmin = 2, nmax = 18)
# ├─ "tigar"
# │  └─ Series
# │     ├─ Mean: n=446 | value=71.1293
# │     └─ Extrema: n=446 | value=(min = 28.96, max = 338.82, nmin = 2, nmax = 3)
# ├─ "kenwood"
# │  └─ Series
# │     ├─ Mean: n=855 | value=219.136
# │     └─ Extrema: n=855 | value=(min = 21.88, max = 1184.05, nmin = 4, nmax = 1)
# ├─ "asustor"
# │  └─ Series
# │     ├─ Mean: n=2 | value=377.1
# │     └─ Extrema: n=2 | value=(min = 243.96, max = 510.24, nmin = 1, nmax = 1)
# ├─ "leadbros"
# │  └─ Series
# │     ├─ Mean: n=208 | value=226.947
# │     └─ Extrema: n=208 | value=(min = 102.71, max = 1377.13, nmin = 1, nmax = 2)
# ├─ "transcend"
# │  └─ Series
# │     ├─ Mean: n=1022 | value=49.8806
# │     └─ Extrema: n=1022 | value=(min = 4.12, max = 293.44, nmin = 1, nmax = 1)
# ├─ "tcl"
# │  └─ Series
# │     ├─ Mean: n=1357 | value=249.453
# │     └─ Extrema: n=1357 | value=(min = 141.06, max = 821.87, nmin = 1, nmax = 6)
# ├─ "dji"
# │  └─ Series
# │     ├─ Mean: n=149 | value=785.416
# │     └─ Extrema: n=149 | value=(min = 100.36, max = 1668.64, nmin = 3, nmax = 1)
# ├─ "epson"
# │  └─ Series
# │     ├─ Mean: n=1475 | value=232.013
# │     └─ Extrema: n=1475 | value=(min = 4.09, max = 1119.46, nmin = 6, nmax = 1)
# ├─ "goodyear"
# │  └─ Series
# │     ├─ Mean: n=1149 | value=103.708
# │     └─ Extrema: n=1149 | value=(min = 43.76, max = 471.83, nmin = 45, nmax = 1)
# ├─ "ikea"
# │  └─ Series
# │     ├─ Mean: n=214 | value=43.1386
# │     └─ Extrema: n=214 | value=(min = 4.09, max = 754.79, nmin = 50, nmax = 1)
# ├─ "roingto"
# │  └─ Series
# │     ├─ Mean: n=25 | value=218.474
# │     └─ Extrema: n=25 | value=(min = 202.06, max = 262.04, nmin = 9, nmax = 3)
# ├─ "navien"
# │  └─ Series
# │     ├─ Mean: n=557 | value=606.72
# │     └─ Extrema: n=557 | value=(min = 506.65, max = 2265.18, nmin = 3, nmax = 5)
# ├─ "lego"
# │  └─ Series
# │     ├─ Mean: n=330 | value=64.1432
# │     └─ Extrema: n=330 | value=(min = 2.57, max = 439.91, nmin = 1, nmax = 4)
# ├─ "dauscher"
# │  └─ Series
# │     ├─ Mean: n=4221 | value=206.123
# │     └─ Extrema: n=4221 | value=(min = 7.7, max = 952.38, nmin = 15, nmax = 15)
# ├─ "timberk"
# │  └─ Series
# │     ├─ Mean: n=713 | value=43.0632
# │     └─ Extrema: n=713 | value=(min = 36.01, max = 127.13, nmin = 8, nmax = 1)
# ├─ "respect"
# │  └─ Series
# │     ├─ Mean: n=4740 | value=81.564
# │     └─ Extrema: n=4740 | value=(min = 19.31, max = 134.11, nmin = 4, nmax = 1)
# ├─ "yokohama"
# │  └─ Series
# │     ├─ Mean: n=2633 | value=92.9327
# │     └─ Extrema: n=2633 | value=(min = 37.32, max = 230.38, nmin = 2, nmax = 2)
# ├─ "lanvin"
# │  └─ Series
# │     ├─ Mean: n=859 | value=42.2531
# │     └─ Extrema: n=859 | value=(min = 25.59, max = 82.8, nmin = 5, nmax = 2)
# ├─ "wallberry"
# │  └─ Series
# │     ├─ Mean: n=43 | value=12.5035
# │     └─ Extrema: n=43 | value=(min = 9.76, max = 19.18, nmin = 1, nmax = 2)
# ├─ "willmark"
# │  └─ Series
# │     ├─ Mean: n=660 | value=21.2127
# │     └─ Extrema: n=660 | value=(min = 7.7, max = 162.14, nmin = 162, nmax = 2)
# ├─ "dewalt"
# │  └─ Series
# │     ├─ Mean: n=506 | value=194.621
# │     └─ Extrema: n=506 | value=(min = 41.84, max = 891.91, nmin = 6, nmax = 1)
# ├─ "lenovo"
# │  └─ Series
# │     ├─ Mean: n=6547 | value=412.113
# │     └─ Extrema: n=6547 | value=(min = 2.24, max = 1956.27, nmin = 1, nmax = 3)
# ├─ "zeta"
# │  └─ Series
# │     ├─ Mean: n=903 | value=70.8576
# │     └─ Extrema: n=903 | value=(min = 6.41, max = 162.63, nmin = 71, nmax = 1)
# ├─ "olmio"
# │  └─ Series
# │     ├─ Mean: n=93 | value=37.683
# │     └─ Extrema: n=93 | value=(min = 4.09, max = 55.34, nmin = 3, nmax = 1)
# ├─ "etor"
# │  └─ Series
# │     ├─ Mean: n=234 | value=115.416
# │     └─ Extrema: n=234 | value=(min = 90.09, max = 126.13, nmin = 1, nmax = 130)
# ├─ "caramelia"
# │  └─ Series
# │     ├─ Mean: n=117 | value=33.5779
# │     └─ Extrema: n=117 | value=(min = 15.42, max = 128.68, nmin = 2, nmax = 3)
# ├─ "electrolux"
# │  └─ Series
# │     ├─ Mean: n=1096 | value=207.401
# │     └─ Extrema: n=1096 | value=(min = 14.4, max = 1920.23, nmin = 4, nmax = 1)
# ├─ "msi"
# │  └─ Series
# │     ├─ Mean: n=412 | value=624.645
# │     └─ Extrema: n=412 | value=(min = 9.76, max = 2574.04, nmin = 2, nmax = 2)
# ├─ "ea"
# │  └─ Series
# │     ├─ Mean: n=654 | value=62.7576
# │     └─ Extrema: n=654 | value=(min = 48.37, max = 74.39, nmin = 60, nmax = 21)
# ├─ "picard"
# │  └─ Series
# │     ├─ Mean: n=49 | value=96.0806
# │     └─ Extrema: n=49 | value=(min = 24.45, max = 270.28, nmin = 1, nmax = 1)
# ├─ "crown"
# │  └─ Series
# │     ├─ Mean: n=961 | value=54.3377
# │     └─ Extrema: n=961 | value=(min = 3.83, max = 282.38, nmin = 1, nmax = 1)
# ├─ "bethesda"
# │  └─ Series
# │     ├─ Mean: n=22 | value=24.8809
# │     └─ Extrema: n=22 | value=(min = 7.72, max = 48.81, nmin = 10, nmax = 1)
# ├─ "tp-link"
# │  └─ Series
# │     ├─ Mean: n=1155 | value=75.5949
# │     └─ Extrema: n=1155 | value=(min = 5.82, max = 159.33, nmin = 1, nmax = 143)
# ├─ "volta"
# │  └─ Series
# │     ├─ Mean: n=283 | value=42.9718
# │     └─ Extrema: n=283 | value=(min = 5.25, max = 141.57, nmin = 1, nmax = 1)
# ├─ "oasis"
# │  └─ Series
# │     ├─ Mean: n=1094 | value=36.9011
# │     └─ Extrema: n=1094 | value=(min = 7.18, max = 220.26, nmin = 1, nmax = 1)
# ├─ "kapsen"
# │  └─ Series
# │     ├─ Mean: n=1653 | value=49.1331
# │     └─ Extrema: n=1653 | value=(min = 25.48, max = 321.81, nmin = 2, nmax = 1)
# ├─ "nokia"
# │  └─ Series
# │     ├─ Mean: n=2640 | value=87.5925
# │     └─ Extrema: n=2640 | value=(min = 10.27, max = 630.65, nmin = 2, nmax = 3)
# ├─ "texet"
# │  └─ Series
# │     ├─ Mean: n=667 | value=23.1721
# │     └─ Extrema: n=667 | value=(min = 6.67, max = 120.7, nmin = 19, nmax = 1)
# ├─ "shell"
# │  └─ Series
# │     ├─ Mean: n=124 | value=21.0791
# │     └─ Extrema: n=124 | value=(min = 4.25, max = 34.75, nmin = 1, nmax = 1)
# ├─ "fly"
# │  └─ Series
# │     ├─ Mean: n=279 | value=215.669
# │     └─ Extrema: n=279 | value=(min = 8.37, max = 2264.92, nmin = 5, nmax = 1)
# ├─ "vitek"
# │  └─ Series
# │     ├─ Mean: n=5423 | value=42.6831
# │     └─ Extrema: n=5423 | value=(min = 5.12, max = 231.64, nmin = 2, nmax = 7)
# ├─ "vinzer"
# │  └─ Series
# │     ├─ Mean: n=69 | value=61.4493
# │     └─ Extrema: n=69 | value=(min = 9.24, max = 257.15, nmin = 1, nmax = 1)
# ├─ "microlab"
# │  └─ Series
# │     ├─ Mean: n=345 | value=55.9345
# │     └─ Extrema: n=345 | value=(min = 7.21, max = 316.58, nmin = 2, nmax = 3)
# ├─ "polaris"
# │  └─ Series
# │     ├─ Mean: n=3545 | value=47.5226
# │     └─ Extrema: n=3545 | value=(min = 2.71, max = 328.4, nmin = 1, nmax = 1)
# ├─ "gigabyte"
# │  └─ Series
# │     ├─ Mean: n=466 | value=220.614
# │     └─ Extrema: n=466 | value=(min = 2.76, max = 1544.18, nmin = 1, nmax = 1)
# ├─ "llorens"
# │  └─ Series
# │     ├─ Mean: n=201 | value=43.2977
# │     └─ Extrema: n=201 | value=(min = 19.8, max = 87.49, nmin = 2, nmax = 2)
# ├─ "bq"
# │  └─ Series
# │     ├─ Mean: n=656 | value=50.5437
# │     └─ Extrema: n=656 | value=(min = 9.86, max = 174.53, nmin = 3, nmax = 1)
# ├─ "matador"
# │  └─ Series
# │     ├─ Mean: n=2504 | value=57.4213
# │     └─ Extrema: n=2504 | value=(min = 28.31, max = 413.09, nmin = 1, nmax = 2)
# ├─ "ibox"
# │  └─ Series
# │     ├─ Mean: n=455 | value=86.2071
# │     └─ Extrema: n=455 | value=(min = 43.5, max = 175.04, nmin = 5, nmax = 8)
# ├─ "bestoy"
# │  └─ Series
# │     ├─ Mean: n=201 | value=63.6704
# │     └─ Extrema: n=201 | value=(min = 46.33, max = 72.07, nmin = 32, nmax = 113)
# ├─ "apacer"
# │  └─ Series
# │     ├─ Mean: n=601 | value=40.4542
# │     └─ Extrema: n=601 | value=(min = 4.09, max = 134.09, nmin = 2, nmax = 1)
# ├─ "huter"
# │  └─ Series
# │     ├─ Mean: n=1201 | value=170.23
# │     └─ Extrema: n=1201 | value=(min = 20.31, max = 1412.62, nmin = 1, nmax = 2)
# ├─ "pioneer"
# │  └─ Series
# │     ├─ Mean: n=1614 | value=120.566
# │     └─ Extrema: n=1614 | value=(min = 18.33, max = 617.78, nmin = 1, nmax = 1)
# ├─ "maxwell"
# │  └─ Series
# │     ├─ Mean: n=825 | value=27.8394
# │     └─ Extrema: n=825 | value=(min = 5.89, max = 71.82, nmin = 2, nmax = 42)
# ├─ "ecotex"
# │  └─ Series
# │     ├─ Mean: n=54 | value=26.4419
# │     └─ Extrema: n=54 | value=(min = 8.16, max = 69.5, nmin = 1, nmax = 11)
# ├─ "nexen"
# │  └─ Series
# │     ├─ Mean: n=755 | value=71.2648
# │     └─ Extrema: n=755 | value=(min = 32.85, max = 184.05, nmin = 1, nmax = 1)
# ├─ "similac"
# │  └─ Series
# │     ├─ Mean: n=22 | value=11.0577
# │     └─ Extrema: n=22 | value=(min = 3.57, max = 15.54, nmin = 3, nmax = 2)
# ├─ "millionaire"
# │  └─ Series
# │     ├─ Mean: n=121 | value=76.5462
# │     └─ Extrema: n=121 | value=(min = 61.52, max = 79.02, nmin = 10, nmax = 97)
# ├─ "toshiba"
# │  └─ Series
# │     ├─ Mean: n=341 | value=254.23
# │     └─ Extrema: n=341 | value=(min = 11.56, max = 771.68, nmin = 1, nmax = 3)
# ├─ "tunga"
# │  └─ Series
# │     ├─ Mean: n=2375 | value=36.1605
# │     └─ Extrema: n=2375 | value=(min = 23.68, max = 89.53, nmin = 5, nmax = 1)
# ├─ "vega"
# │  └─ Series
# │     ├─ Mean: n=349 | value=27.0888
# │     └─ Extrema: n=349 | value=(min = 5.92, max = 70.66, nmin = 5, nmax = 3)
# ├─ "edufun"
# │  └─ Series
# │     ├─ Mean: n=102 | value=122.723
# │     └─ Extrema: n=102 | value=(min = 97.79, max = 175.01, nmin = 35, nmax = 11)
# ├─ "jinga"
# │  └─ Series
# │     ├─ Mean: n=133 | value=20.6856
# │     └─ Extrema: n=133 | value=(min = 7.99, max = 94.97, nmin = 2, nmax = 3)
# ├─ "gorenje"
# │  └─ Series
# │     ├─ Mean: n=697 | value=205.396
# │     └─ Extrema: n=697 | value=(min = 17.99, max = 1377.29, nmin = 44, nmax = 1)
# ├─ "element"
# │  └─ Series
# │     ├─ Mean: n=649 | value=125.4
# │     └─ Extrema: n=649 | value=(min = 20.59, max = 133.85, nmin = 1, nmax = 40)
# ├─ "xerox"
# │  └─ Series
# │     ├─ Mean: n=59 | value=151.377
# │     └─ Extrema: n=59 | value=(min = 87.26, max = 289.31, nmin = 1, nmax = 3)
# ├─ "brother"
# │  └─ Series
# │     ├─ Mean: n=223 | value=164.231
# │     └─ Extrema: n=223 | value=(min = 83.87, max = 2194.36, nmin = 1, nmax = 2)
# ├─ "thomas"
# │  └─ Series
# │     ├─ Mean: n=778 | value=338.467
# │     └─ Extrema: n=778 | value=(min = 141.29, max = 540.53, nmin = 1, nmax = 1)
# ├─ "conceptclub"
# │  └─ Series
# │     ├─ Mean: n=285 | value=34.2876
# │     └─ Extrema: n=285 | value=(min = 8.24, max = 69.5, nmin = 2, nmax = 2)
# ├─ "skad"
# │  └─ Series
# │     ├─ Mean: n=510 | value=226.165
# │     └─ Extrema: n=510 | value=(min = 144.66, max = 387.65, nmin = 1, nmax = 1)
# ├─ "yunteng"
# │  └─ Series
# │     ├─ Mean: n=9 | value=70.0722
# │     └─ Extrema: n=9 | value=(min = 54.06, max = 102.96, nmin = 1, nmax = 1)
# ├─ "remington"
# │  └─ Series
# │     ├─ Mean: n=652 | value=61.0994
# │     └─ Extrema: n=652 | value=(min = 9.24, max = 362.92, nmin = 5, nmax = 7)
# ├─ "nutricia"
# │  └─ Series
# │     ├─ Mean: n=70 | value=7.809
# │     └─ Extrema: n=70 | value=(min = 1.45, max = 11.02, nmin = 1, nmax = 41)
# ├─ "rondell"
# │  └─ Series
# │     ├─ Mean: n=629 | value=52.5289
# │     └─ Extrema: n=629 | value=(min = 5.12, max = 149.27, nmin = 1, nmax = 15)
# ├─ "genesis"
# │  └─ Series
# │     ├─ Mean: n=515 | value=49.6317
# │     └─ Extrema: n=515 | value=(min = 38.61, max = 168.86, nmin = 3, nmax = 4)
# ├─ "lider"
# │  └─ Series
# │     ├─ Mean: n=388 | value=421.386
# │     └─ Extrema: n=388 | value=(min = 123.01, max = 502.18, nmin = 1, nmax = 38)
# ├─ "marshall"
# │  └─ Series
# │     ├─ Mean: n=255 | value=117.664
# │     └─ Extrema: n=255 | value=(min = 33.44, max = 767.07, nmin = 1, nmax = 3)
# ├─ "askona"
# │  └─ Series
# │     ├─ Mean: n=421 | value=168.979
# │     └─ Extrema: n=421 | value=(min = 25.9, max = 931.3, nmin = 1, nmax = 1)
# ├─ "komfort-s"
# │  └─ Series
# │     ├─ Mean: n=60 | value=272.887
# │     └─ Extrema: n=60 | value=(min = 39.36, max = 386.6, nmin = 7, nmax = 25)
# ├─ "nexpero"
# │  └─ Series
# │     ├─ Mean: n=329 | value=74.5868
# │     └─ Extrema: n=329 | value=(min = 16.99, max = 82.63, nmin = 4, nmax = 77)
# ├─ "habilead"
# │  └─ Series
# │     ├─ Mean: n=352 | value=57.0599
# │     └─ Extrema: n=352 | value=(min = 29.34, max = 97.3, nmin = 8, nmax = 1)
# ├─ "elenberg"
# │  └─ Series
# │     ├─ Mean: n=4655 | value=34.5099
# │     └─ Extrema: n=4655 | value=(min = 4.35, max = 437.57, nmin = 3, nmax = 18)
# ├─ "dior"
# │  └─ Series
# │     ├─ Mean: n=443 | value=127.492
# │     └─ Extrema: n=443 | value=(min = 77.22, max = 409.02, nmin = 1, nmax = 2)
# ├─ "genau"
# │  └─ Series
# │     ├─ Mean: n=112 | value=265.447
# │     └─ Extrema: n=112 | value=(min = 39.87, max = 611.32, nmin = 9, nmax = 1)
# ├─ "beko"
# │  └─ Series
# │     ├─ Mean: n=3884 | value=232.839
# │     └─ Extrema: n=3884 | value=(min = 100.31, max = 1704.9, nmin = 2, nmax = 2)
# ├─ "moulinex"
# │  └─ Series
# │     ├─ Mean: n=704 | value=125.267
# │     └─ Extrema: n=704 | value=(min = 30.61, max = 445.29, nmin = 1, nmax = 1)
# ├─ "rooman"
# │  └─ Series
# │     ├─ Mean: n=219 | value=59.5558
# │     └─ Extrema: n=219 | value=(min = 23.68, max = 64.61, nmin = 4, nmax = 95)
# ├─ "jet"
# │  └─ Series
# │     ├─ Mean: n=262 | value=31.2282
# │     └─ Extrema: n=262 | value=(min = 12.84, max = 36.01, nmin = 9, nmax = 15)
# ├─ "starline"
# │  └─ Series
# │     ├─ Mean: n=2731 | value=141.936
# │     └─ Extrema: n=2731 | value=(min = 67.96, max = 441.2, nmin = 1, nmax = 1)
# ├─ "hansa"
# │  └─ Series
# │     ├─ Mean: n=1540 | value=245.663
# │     └─ Extrema: n=1540 | value=(min = 48.88, max = 656.13, nmin = 262, nmax = 6)
# ├─ "elite"
# │  └─ Series
# │     ├─ Mean: n=13 | value=5.86231
# │     └─ Extrema: n=13 | value=(min = 4.52, max = 10.38, nmin = 7, nmax = 1)
# ├─ "gigawatt"
# │  └─ Series
# │     ├─ Mean: n=491 | value=92.7751
# │     └─ Extrema: n=491 | value=(min = 64.35, max = 303.2, nmin = 1, nmax = 3)
# ├─ "powertrac"
# │  └─ Series
# │     ├─ Mean: n=1651 | value=40.7846
# │     └─ Extrema: n=1651 | value=(min = 25.48, max = 95.24, nmin = 13, nmax = 1)
# ├─ "gislaved"
# │  └─ Series
# │     ├─ Mean: n=422 | value=79.9533
# │     └─ Extrema: n=422 | value=(min = 34.24, max = 162.42, nmin = 1, nmax = 2)
# ├─ "nan"
# │  └─ Series
# │     ├─ Mean: n=89 | value=10.6821
# │     └─ Extrema: n=89 | value=(min = 6.36, max = 13.36, nmin = 1, nmax = 4)
# ├─ "sava"
# │  └─ Series
# │     ├─ Mean: n=182 | value=101.738
# │     └─ Extrema: n=182 | value=(min = 33.98, max = 503.75, nmin = 2, nmax = 1)
# ├─ "pt-group"
# │  └─ Series
# │     ├─ Mean: n=113 | value=212.194
# │     └─ Extrema: n=113 | value=(min = 64.35, max = 270.28, nmin = 3, nmax = 9)
# ├─ "aerocool"
# │  └─ Series
# │     ├─ Mean: n=379 | value=74.0512
# │     └─ Extrema: n=379 | value=(min = 2.7, max = 185.33, nmin = 2, nmax = 9)
# ├─ "kingston"
# │  └─ Series
# │     ├─ Mean: n=1387 | value=46.9482
# │     └─ Extrema: n=1387 | value=(min = 3.36, max = 517.38, nmin = 2, nmax = 1)
# ├─ "defender"
# │  └─ Series
# │     ├─ Mean: n=652 | value=11.4887
# │     └─ Extrema: n=652 | value=(min = 2.55, max = 57.66, nmin = 2, nmax = 10)
# ├─ "kolner"
# │  └─ Series
# │     ├─ Mean: n=128 | value=38.3445
# │     └─ Extrema: n=128 | value=(min = 7.72, max = 101.93, nmin = 5, nmax = 3)
# ├─ "janome"
# │  └─ Series
# │     ├─ Mean: n=2142 | value=237.297
# │     └─ Extrema: n=2142 | value=(min = 98.54, max = 1741.24, nmin = 2, nmax = 4)
# ├─ "perilla"
# │  └─ Series
# │     ├─ Mean: n=636 | value=29.8351
# │     └─ Extrema: n=636 | value=(min = 14.65, max = 69.24, nmin = 97, nmax = 5)
# ├─ "sokolov"
# │  └─ Series
# │     ├─ Mean: n=2123 | value=151.567
# │     └─ Extrema: n=2123 | value=(min = 5.02, max = 785.26, nmin = 1, nmax = 1)
# ├─ "brw"
# │  └─ Series
# │     ├─ Mean: n=1262 | value=232.26
# │     └─ Extrema: n=1262 | value=(min = 15.44, max = 1165.28, nmin = 1, nmax = 3)
# ├─ "harper"
# │  └─ Series
# │     ├─ Mean: n=457 | value=85.3636
# │     └─ Extrema: n=457 | value=(min = 2.81, max = 398.21, nmin = 7, nmax = 1)
# ├─ "joie"
# │  └─ Series
# │     ├─ Mean: n=400 | value=159.547
# │     └─ Extrema: n=400 | value=(min = 53.8, max = 372.98, nmin = 4, nmax = 2)
# ├─ "artmusical"
# │  └─ Series
# │     ├─ Mean: n=163 | value=149.452
# │     └─ Extrema: n=163 | value=(min = 97.81, max = 386.11, nmin = 40, nmax = 12)
# ├─ "bourjois"
# │  └─ Series
# │     ├─ Mean: n=102 | value=9.21843
# │     └─ Extrema: n=102 | value=(min = 5.78, max = 14.29, nmin = 1, nmax = 1)
# ├─ "darina"
# │  └─ Series
# │     ├─ Mean: n=173 | value=169.904
# │     └─ Extrema: n=173 | value=(min = 33.44, max = 406.68, nmin = 33, nmax = 2)
# ├─ "omron"
# │  └─ Series
# │     ├─ Mean: n=1698 | value=60.2251
# │     └─ Extrema: n=1698 | value=(min = 6.16, max = 289.3, nmin = 1, nmax = 1)
# ├─ "kumho"
# │  └─ Series
# │     ├─ Mean: n=130 | value=69.6898
# │     └─ Extrema: n=130 | value=(min = 40.03, max = 154.44, nmin = 4, nmax = 2)
# ├─ "karcher"
# │  └─ Series
# │     ├─ Mean: n=1451 | value=244.013
# │     └─ Extrema: n=1451 | value=(min = 63.45, max = 1284.46, nmin = 1, nmax = 1)
# ├─ "wingoffly"
# │  └─ Series
# │     ├─ Mean: n=279 | value=115.523
# │     └─ Extrema: n=279 | value=(min = 107.83, max = 123.45, nmin = 1, nmax = 3)
# ├─ "jordan"
# │  └─ Series
# │     ├─ Mean: n=42 | value=123.415
# │     └─ Extrema: n=42 | value=(min = 73.34, max = 190.46, nmin = 1, nmax = 3)
# ├─ "goodride"
# │  └─ Series
# │     ├─ Mean: n=782 | value=46.2823
# │     └─ Extrema: n=782 | value=(min = 26.08, max = 98.84, nmin = 2, nmax = 1)
# ├─ "efremov"
# │  └─ Series
# │     ├─ Mean: n=172 | value=142.281
# │     └─ Extrema: n=172 | value=(min = 55.09, max = 299.62, nmin = 6, nmax = 4)
# ├─ "roadx"
# │  └─ Series
# │     ├─ Mean: n=1658 | value=55.068
# │     └─ Extrema: n=1658 | value=(min = 24.97, max = 332.57, nmin = 11, nmax = 2)
# ├─ "boccia"
# │  └─ Series
# │     ├─ Mean: n=123 | value=122.167
# │     └─ Extrema: n=123 | value=(min = 56.63, max = 1050.73, nmin = 3, nmax = 1)
# ├─ "romanson"
# │  └─ Series
# │     ├─ Mean: n=36 | value=123.387
# │     └─ Extrema: n=36 | value=(min = 91.12, max = 147.75, nmin = 3, nmax = 1)
# ├─ "michelin"
# │  └─ Series
# │     ├─ Mean: n=999 | value=130.494
# │     └─ Extrema: n=999 | value=(min = 37.32, max = 624.21, nmin = 2, nmax = 2)
# ├─ "gemei"
# │  └─ Series
# │     ├─ Mean: n=30 | value=24.1857
# │     └─ Extrema: n=30 | value=(min = 21.88, max = 25.48, nmin = 10, nmax = 19)
# ├─ "iiyama"
# │  └─ Series
# │     ├─ Mean: n=5 | value=209.68
# │     └─ Extrema: n=5 | value=(min = 149.22, max = 295.99, nmin = 1, nmax = 1)
# ├─ "gopro"
# │  └─ Series
# │     ├─ Mean: n=144 | value=463.91
# │     └─ Extrema: n=144 | value=(min = 38.58, max = 849.19, nmin = 1, nmax = 1)
# ├─ "ecocool"
# │  └─ Series
# │     ├─ Mean: n=105 | value=92.1725
# │     └─ Extrema: n=105 | value=(min = 56.6, max = 159.57, nmin = 14, nmax = 3)
# ├─ "bars"
# │  └─ Series
# │     ├─ Mean: n=1107 | value=62.131
# │     └─ Extrema: n=1107 | value=(min = 30.63, max = 164.81, nmin = 5, nmax = 1)
# ├─ "baldessarini"
# │  └─ Series
# │     ├─ Mean: n=5 | value=58.652
# │     └─ Extrema: n=5 | value=(min = 58.62, max = 58.69, nmin = 2, nmax = 2)
# ├─ "almacom"
# │  └─ Series
# │     ├─ Mean: n=332 | value=165.109
# │     └─ Extrema: n=332 | value=(min = 12.1, max = 1540.83, nmin = 2, nmax = 1)
# ├─ "roadstone"
# │  └─ Series
# │     ├─ Mean: n=264 | value=66.7495
# │     └─ Extrema: n=264 | value=(min = 25.74, max = 126.9, nmin = 3, nmax = 1)
# ├─ "belecoo"
# │  └─ Series
# │     ├─ Mean: n=745 | value=119.358
# │     └─ Extrema: n=745 | value=(min = 88.33, max = 177.04, nmin = 1, nmax = 1)
# ├─ "ergo"
# │  └─ Series
# │     ├─ Mean: n=164 | value=272.865
# │     └─ Extrema: n=164 | value=(min = 2.52, max = 512.24, nmin = 1, nmax = 2)
# ├─ "dwt"
# │  └─ Series
# │     ├─ Mean: n=191 | value=82.6372
# │     └─ Extrema: n=191 | value=(min = 18.26, max = 266.92, nmin = 2, nmax = 1)
# ├─ "kivi"
# │  └─ Series
# │     ├─ Mean: n=1365 | value=277.432
# │     └─ Extrema: n=1365 | value=(min = 107.85, max = 694.74, nmin = 3, nmax = 2)
# ├─ "nutrex"
# │  └─ Series
# │     ├─ Mean: n=40 | value=27.5568
# │     └─ Extrema: n=40 | value=(min = 14.03, max = 42.6, nmin = 4, nmax = 1)
# ├─ "panasonic"
# │  └─ Series
# │     ├─ Mean: n=1439 | value=99.0201
# │     └─ Extrema: n=1439 | value=(min = 3.6, max = 2547.14, nmin = 3, nmax = 1)
# ├─ "pirelli"
# │  └─ Series
# │     ├─ Mean: n=534 | value=101.904
# │     └─ Extrema: n=534 | value=(min = 40.93, max = 586.89, nmin = 3, nmax = 1)
# ├─ "kicx"
# │  └─ Series
# │     ├─ Mean: n=358 | value=86.3031
# │     └─ Extrema: n=358 | value=(min = 15.44, max = 384.57, nmin = 2, nmax = 10)
# ├─ "makita"
# │  └─ Series
# │     ├─ Mean: n=370 | value=289.08
# │     └─ Extrema: n=370 | value=(min = 19.75, max = 2018.56, nmin = 1, nmax = 1)
# ├─ "coballe"
# │  └─ Series
# │     ├─ Mean: n=101 | value=98.5194
# │     └─ Extrema: n=101 | value=(min = 65.55, max = 230.38, nmin = 5, nmax = 12)
# ├─ "delonghi"
# │  └─ Series
# │     ├─ Mean: n=636 | value=359.512
# │     └─ Extrema: n=636 | value=(min = 48.88, max = 2059.18, nmin = 1, nmax = 3)
# ├─ "montale"
# │  └─ Series
# │     ├─ Mean: n=961 | value=93.5703
# │     └─ Extrema: n=961 | value=(min = 10.3, max = 229.7, nmin = 1, nmax = 1)
# ├─ "infinity"
# │  └─ Series
# │     ├─ Mean: n=30 | value=99.1873
# │     └─ Extrema: n=30 | value=(min = 43.76, max = 108.11, nmin = 1, nmax = 20)
# ├─ "hoco"
# │  └─ Series
# │     ├─ Mean: n=231 | value=18.3307
# │     └─ Extrema: n=231 | value=(min = 2.57, max = 33.44, nmin = 8, nmax = 1)
# ├─ "ovation"
# │  └─ Series
# │     ├─ Mean: n=205 | value=50.8704
# │     └─ Extrema: n=205 | value=(min = 30.37, max = 267.45, nmin = 4, nmax = 1)
# ├─ "rapid"
# │  └─ Series
# │     ├─ Mean: n=25 | value=15.42
# │     └─ Extrema: n=25 | value=(min = 15.42, max = 15.42, nmin = 25, nmax = 25)
# ├─ "svc"
# │  └─ Series
# │     ├─ Mean: n=183 | value=43.4142
# │     └─ Extrema: n=183 | value=(min = 5.12, max = 448.48, nmin = 20, nmax = 1)
# ├─ "aqua"
# │  └─ Series
# │     ├─ Mean: n=221 | value=33.9682
# │     └─ Extrema: n=221 | value=(min = 30.09, max = 131.25, nmin = 15, nmax = 2)
# ├─ "amd"
# │  └─ Series
# │     ├─ Mean: n=241 | value=185.613
# │     └─ Extrema: n=241 | value=(min = 18.51, max = 540.3, nmin = 4, nmax = 1)
# ├─ "garanterm"
# │  └─ Series
# │     ├─ Mean: n=34 | value=93.9994
# │     └─ Extrema: n=34 | value=(min = 79.28, max = 109.63, nmin = 3, nmax = 2)
# ├─ "changhong"
# │  └─ Series
# │     ├─ Mean: n=295 | value=255.428
# │     └─ Extrema: n=295 | value=(min = 128.68, max = 416.97, nmin = 8, nmax = 8)
# ├─ "grow-with-me"
# │  └─ Series
# │     ├─ Mean: n=119 | value=35.9189
# │     └─ Extrema: n=119 | value=(min = 35.77, max = 37.32, nmin = 41, nmax = 11)
# ├─ "rowenta"
# │  └─ Series
# │     ├─ Mean: n=2064 | value=56.367
# │     └─ Extrema: n=2064 | value=(min = 12.61, max = 239.13, nmin = 1, nmax = 2)
# ├─ "inoi"
# │  └─ Series
# │     ├─ Mean: n=238 | value=46.5955
# │     └─ Extrema: n=238 | value=(min = 5.12, max = 114.52, nmin = 4, nmax = 1)
# ├─ "maxler"
# │  └─ Series
# │     ├─ Mean: n=119 | value=26.4721
# │     └─ Extrema: n=119 | value=(min = 8.75, max = 58.95, nmin = 2, nmax = 9)
# ├─ "ritmix"
# │  └─ Series
# │     ├─ Mean: n=391 | value=18.6533
# │     └─ Extrema: n=391 | value=(min = 0.87, max = 114.34, nmin = 5, nmax = 1)
# ├─ "axis"
# │  └─ Series
# │     ├─ Mean: n=98 | value=139.678
# │     └─ Extrema: n=98 | value=(min = 95.24, max = 244.28, nmin = 6, nmax = 2)
# ├─ "thrustmaster"
# │  └─ Series
# │     ├─ Mean: n=8 | value=317.545
# │     └─ Extrema: n=8 | value=(min = 192.8, max = 566.04, nmin = 1, nmax = 1)
# ├─ "pasabahce"
# │  └─ Series
# │     ├─ Mean: n=76 | value=6.41539
# │     └─ Extrema: n=76 | value=(min = 2.99, max = 13.28, nmin = 1, nmax = 3)
# ├─ "chicco"
# │  └─ Series
# │     ├─ Mean: n=330 | value=112.261
# │     └─ Extrema: n=330 | value=(min = 5.92, max = 360.34, nmin = 1, nmax = 6)
# ├─ "nike"
# │  └─ Series
# │     ├─ Mean: n=394 | value=105.284
# │     └─ Extrema: n=394 | value=(min = 19.31, max = 218.77, nmin = 1, nmax = 10)
# ├─ "bridgestone"
# │  └─ Series
# │     ├─ Mean: n=813 | value=146.843
# │     └─ Extrema: n=813 | value=(min = 34.75, max = 444.28, nmin = 1, nmax = 2)
# ├─ "elikor"
# │  └─ Series
# │     ├─ Mean: n=47 | value=99.6796
# │     └─ Extrema: n=47 | value=(min = 52.51, max = 291.64, nmin = 1, nmax = 1)
# ├─ "asus"
# │  └─ Series
# │     ├─ Mean: n=3062 | value=544.027
# │     └─ Extrema: n=3062 | value=(min = 9.5, max = 2570.18, nmin = 1, nmax = 6)
# ├─ "native"
# │  └─ Series
# │     ├─ Mean: n=36 | value=144.12
# │     └─ Extrema: n=36 | value=(min = 144.12, max = 144.12, nmin = 36, nmax = 36)
# ├─ "mart"
# │  └─ Series
# │     ├─ Mean: n=286 | value=53.5376
# │     └─ Extrema: n=286 | value=(min = 8.98, max = 514.79, nmin = 2, nmax = 2)
# ├─ "aimoto"
# │  └─ Series
# │     ├─ Mean: n=303 | value=55.6033
# │     └─ Extrema: n=303 | value=(min = 43.76, max = 90.34, nmin = 2, nmax = 1)
# ├─ "hertz"
# │  └─ Series
# │     ├─ Mean: n=102 | value=110.864
# │     └─ Extrema: n=102 | value=(min = 33.53, max = 809.21, nmin = 1, nmax = 1)
# ├─ "jaguar"
# │  └─ Series
# │     ├─ Mean: n=301 | value=146.576
# │     └─ Extrema: n=301 | value=(min = 64.48, max = 1136.97, nmin = 7, nmax = 2)
# ├─ "hyperx"
# │  └─ Series
# │     ├─ Mean: n=295 | value=79.1543
# │     └─ Extrema: n=295 | value=(min = 8.15, max = 231.41, nmin = 1, nmax = 2)
# ├─ "vivo"
# │  └─ Series
# │     ├─ Mean: n=1914 | value=269.683
# │     └─ Extrema: n=1914 | value=(min = 102.94, max = 797.94, nmin = 63, nmax = 75)
# ├─ "nika"
# │  └─ Series
# │     ├─ Mean: n=1371 | value=47.5022
# │     └─ Extrema: n=1371 | value=(min = 5.12, max = 158.87, nmin = 2, nmax = 3)
# ├─ "resanta"
# │  └─ Series
# │     ├─ Mean: n=102 | value=123.627
# │     └─ Extrema: n=102 | value=(min = 12.04, max = 573.73, nmin = 1, nmax = 4)
# ├─ "denzel"
# │  └─ Series
# │     ├─ Mean: n=108 | value=250.164
# │     └─ Extrema: n=108 | value=(min = 22.8, max = 900.26, nmin = 1, nmax = 1)
# ├─ "pocketbook"
# │  └─ Series
# │     ├─ Mean: n=369 | value=142.749
# │     └─ Extrema: n=369 | value=(min = 100.13, max = 254.81, nmin = 5, nmax = 2)
# ├─ "mazzini"
# │  └─ Series
# │     ├─ Mean: n=385 | value=40.7498
# │     └─ Extrema: n=385 | value=(min = 28.31, max = 97.81, nmin = 7, nmax = 1)
# ├─ "adil"
# │  └─ Series
# │     ├─ Mean: n=256 | value=110.537
# │     └─ Extrema: n=256 | value=(min = 54.06, max = 167.31, nmin = 12, nmax = 3)
# ├─ "petek"
# │  └─ Series
# │     ├─ Mean: n=128 | value=69.7155
# │     └─ Extrema: n=128 | value=(min = 31.92, max = 155.86, nmin = 1, nmax = 2)
# ├─ "danielklein"
# │  └─ Series
# │     ├─ Mean: n=122 | value=38.8343
# │     └─ Extrema: n=122 | value=(min = 23.17, max = 57.14, nmin = 2, nmax = 1)
# ├─ "lorelli-bertoni"
# │  └─ Series
# │     ├─ Mean: n=54 | value=73.7102
# │     └─ Extrema: n=54 | value=(min = 40.93, max = 128.45, nmin = 10, nmax = 3)
# ├─ "aeroforce"
# │  └─ Series
# │     ├─ Mean: n=389 | value=143.146
# │     └─ Extrema: n=389 | value=(min = 24.45, max = 217.25, nmin = 9, nmax = 4)
# ├─ "troyka"
# │  └─ Series
# │     ├─ Mean: n=21 | value=12.6271
# │     └─ Extrema: n=21 | value=(min = 11.35, max = 12.84, nmin = 3, nmax = 18)
# ├─ "baden"
# │  └─ Series
# │     ├─ Mean: n=1539 | value=68.5912
# │     └─ Extrema: n=1539 | value=(min = 28.57, max = 102.71, nmin = 1, nmax = 1)
# ├─ "olmeko"
# │  └─ Series
# │     ├─ Mean: n=42 | value=175.095
# │     └─ Extrema: n=42 | value=(min = 142.84, max = 439.88, nmin = 2, nmax = 1)
# ├─ "plantronics"
# │  └─ Series
# │     ├─ Mean: n=206 | value=49.1941
# │     └─ Extrema: n=206 | value=(min = 8.3, max = 407.41, nmin = 1, nmax = 1)
# ├─ "lubimyjdom"
# │  └─ Series
# │     ├─ Mean: n=4 | value=277.798
# │     └─ Extrema: n=4 | value=(min = 20.59, max = 1026.02, nmin = 2, nmax = 1)
# ├─ "bsn"
# │  └─ Series
# │     ├─ Mean: n=69 | value=52.7288
# │     └─ Extrema: n=69 | value=(min = 22.91, max = 101.03, nmin = 7, nmax = 5)
# ├─ "atlantic"
# │  └─ Series
# │     ├─ Mean: n=125 | value=196.896
# │     └─ Extrema: n=125 | value=(min = 93.7, max = 717.83, nmin = 1, nmax = 1)
# ├─ "sunwide"
# │  └─ Series
# │     ├─ Mean: n=318 | value=54.384
# │     └─ Extrema: n=318 | value=(min = 35.52, max = 84.85, nmin = 1, nmax = 1)
# ├─ "gucci"
# │  └─ Series
# │     ├─ Mean: n=258 | value=102.281
# │     └─ Extrema: n=258 | value=(min = 41.76, max = 563.46, nmin = 4, nmax = 9)
# ├─ "tomfarr"
# │  └─ Series
# │     ├─ Mean: n=185 | value=141.57
# │     └─ Extrema: n=185 | value=(min = 25.74, max = 281.86, nmin = 2, nmax = 3)
# ├─ "bts"
# │  └─ Series
# │     ├─ Mean: n=835 | value=268.824
# │     └─ Extrema: n=835 | value=(min = 22.37, max = 714.3, nmin = 1, nmax = 4)
# ├─ "alteco"
# │  └─ Series
# │     ├─ Mean: n=666 | value=52.946
# │     └─ Extrema: n=666 | value=(min = 12.18, max = 624.0, nmin = 4, nmax = 1)
# ├─ "rivertoys"
# │  └─ Series
# │     ├─ Mean: n=325 | value=159.344
# │     └─ Extrema: n=325 | value=(min = 102.83, max = 398.72, nmin = 3, nmax = 5)
# ├─ "dermacol"
# │  └─ Series
# │     ├─ Mean: n=101 | value=11.6005
# │     └─ Extrema: n=101 | value=(min = 2.57, max = 15.19, nmin = 1, nmax = 1)
# ├─ "prestigio"
# │  └─ Series
# │     ├─ Mean: n=1217 | value=50.7048
# │     └─ Extrema: n=1217 | value=(min = 7.44, max = 257.38, nmin = 19, nmax = 59)
# ├─ "gf"
# │  └─ Series
# │     ├─ Mean: n=46 | value=754.303
# │     └─ Extrema: n=46 | value=(min = 545.7, max = 844.29, nmin = 2, nmax = 10)
# ├─ "creed"
# │  └─ Series
# │     ├─ Mean: n=403 | value=201.026
# │     └─ Extrema: n=403 | value=(min = 16.73, max = 437.33, nmin = 24, nmax = 1)
# ├─ "crucial"
# │  └─ Series
# │     ├─ Mean: n=91 | value=61.2016
# │     └─ Extrema: n=91 | value=(min = 19.41, max = 195.63, nmin = 1, nmax = 1)
# ├─ "jinjianfeng"
# │  └─ Series
# │     ├─ Mean: n=9 | value=34.75
# │     └─ Extrema: n=9 | value=(min = 34.75, max = 34.75, nmin = 9, nmax = 9)
# ├─ "yasin"
# │  └─ Series
# │     ├─ Mean: n=670 | value=245.481
# │     └─ Extrema: n=670 | value=(min = 97.79, max = 524.85, nmin = 32, nmax = 2)
# ├─ "dell"
# │  └─ Series
# │     ├─ Mean: n=169 | value=704.195
# │     └─ Extrema: n=169 | value=(min = 15.42, max = 1887.05, nmin = 1, nmax = 1)
# ├─ "peg-perego"
# │  └─ Series
# │     ├─ Mean: n=184 | value=170.813
# │     └─ Extrema: n=184 | value=(min = 23.17, max = 311.2, nmin = 3, nmax = 2)
# ├─ "sailun"
# │  └─ Series
# │     ├─ Mean: n=133 | value=64.3353
# │     └─ Extrema: n=133 | value=(min = 28.57, max = 312.75, nmin = 1, nmax = 1)
# ├─ "navitel"
# │  └─ Series
# │     ├─ Mean: n=109 | value=97.9052
# │     └─ Extrema: n=109 | value=(min = 51.46, max = 154.42, nmin = 12, nmax = 5)
# ├─ "ubisoft"
# │  └─ Series
# │     ├─ Mean: n=223 | value=26.5652
# │     └─ Extrema: n=223 | value=(min = 7.72, max = 72.05, nmin = 4, nmax = 1)
# ├─ "saturn"
# │  └─ Series
# │     ├─ Mean: n=312 | value=30.5229
# │     └─ Extrema: n=312 | value=(min = 7.7, max = 244.28, nmin = 2, nmax = 5)
# ├─ "gran-stone"
# │  └─ Series
# │     ├─ Mean: n=32 | value=75.9303
# │     └─ Extrema: n=32 | value=(min = 51.28, max = 103.06, nmin = 2, nmax = 1)
# ├─ "luminarc"
# │  └─ Series
# │     ├─ Mean: n=422 | value=57.7715
# │     └─ Extrema: n=422 | value=(min = 7.72, max = 154.03, nmin = 3, nmax = 1)
# ├─ "scovo"
# │  └─ Series
# │     ├─ Mean: n=55 | value=30.0216
# │     └─ Extrema: n=55 | value=(min = 8.39, max = 50.53, nmin = 1, nmax = 24)
# ├─ "cougar"
# │  └─ Series
# │     ├─ Mean: n=70 | value=79.1247
# │     └─ Extrema: n=70 | value=(min = 31.15, max = 231.41, nmin = 1, nmax = 1)
# ├─ "irbis"
# │  └─ Series
# │     ├─ Mean: n=106 | value=73.5565
# │     └─ Extrema: n=106 | value=(min = 9.9, max = 100.39, nmin = 2, nmax = 47)
# ├─ "atlant"
# │  └─ Series
# │     ├─ Mean: n=1079 | value=272.301
# │     └─ Extrema: n=1079 | value=(min = 77.22, max = 524.34, nmin = 4, nmax = 3)
# ├─ "centurion"
# │  └─ Series
# │     ├─ Mean: n=147 | value=87.9909
# │     └─ Extrema: n=147 | value=(min = 82.06, max = 334.37, nmin = 8, nmax = 1)
# ├─ "sven"
# │  └─ Series
# │     ├─ Mean: n=774 | value=35.5063
# │     └─ Extrema: n=774 | value=(min = 1.95, max = 193.03, nmin = 2, nmax = 2)
# ├─ "continental"
# │  └─ Series
# │     ├─ Mean: n=451 | value=141.395
# │     └─ Extrema: n=451 | value=(min = 51.87, max = 502.05, nmin = 1, nmax = 1)
# ├─ "bond"
# │  └─ Series
# │     ├─ Mean: n=11 | value=23.17
# │     └─ Extrema: n=11 | value=(min = 23.17, max = 23.17, nmin = 11, nmax = 11)
# ├─ "maxvi"
# │  └─ Series
# │     ├─ Mean: n=109 | value=14.5368
# │     └─ Extrema: n=109 | value=(min = 7.7, max = 35.78, nmin = 7, nmax = 10)
# ├─ "honor"
# │  └─ Series
# │     ├─ Mean: n=806 | value=232.262
# │     └─ Extrema: n=806 | value=(min = 12.84, max = 746.45, nmin = 5, nmax = 5)
# ├─ "aoteli"
# │  └─ Series
# │     ├─ Mean: n=169 | value=45.2427
# │     └─ Extrema: n=169 | value=(min = 25.16, max = 72.33, nmin = 4, nmax = 1)
# ├─ "damask"
# │  └─ Series
# │     ├─ Mean: n=6 | value=69.0717
# │     └─ Extrema: n=6 | value=(min = 66.93, max = 69.5, nmin = 1, nmax = 5)
# ├─ "alerana"
# │  └─ Series
# │     ├─ Mean: n=5 | value=9.372
# │     └─ Extrema: n=5 | value=(min = 6.18, max = 10.17, nmin = 1, nmax = 4)
# ├─ "novline"
# │  └─ Series
# │     ├─ Mean: n=72 | value=27.4421
# │     └─ Extrema: n=72 | value=(min = 15.57, max = 35.52, nmin = 1, nmax = 2)
# ├─ "delmax"
# │  └─ Series
# │     ├─ Mean: n=140 | value=44.0584
# │     └─ Extrema: n=140 | value=(min = 33.21, max = 107.08, nmin = 11, nmax = 2)
# ├─ "rals"
# │  └─ Series
# │     ├─ Mean: n=244 | value=533.588
# │     └─ Extrema: n=244 | value=(min = 122.94, max = 860.85, nmin = 1, nmax = 25)
# ├─ "yamaha"
# │  └─ Series
# │     ├─ Mean: n=752 | value=373.082
# │     └─ Extrema: n=752 | value=(min = 8.21, max = 2249.97, nmin = 1, nmax = 4)
# ├─ "gerat"
# │  └─ Series
# │     ├─ Mean: n=84 | value=54.2023
# │     └─ Extrema: n=84 | value=(min = 2.32, max = 237.46, nmin = 1, nmax = 2)
# ├─ "akvaton"
# │  └─ Series
# │     ├─ Mean: n=17 | value=217.708
# │     └─ Extrema: n=17 | value=(min = 71.35, max = 518.31, nmin = 1, nmax = 1)
# ├─ "racer"
# │  └─ Series
# │     ├─ Mean: n=172 | value=144.132
# │     └─ Extrema: n=172 | value=(min = 38.1, max = 1480.09, nmin = 6, nmax = 1)
# ├─ "pupa"
# │  └─ Series
# │     ├─ Mean: n=174 | value=13.4302
# │     └─ Extrema: n=174 | value=(min = 6.56, max = 27.45, nmin = 1, nmax = 2)
# ├─ "sennheiser"
# │  └─ Series
# │     ├─ Mean: n=61 | value=98.7697
# │     └─ Extrema: n=61 | value=(min = 6.15, max = 483.67, nmin = 1, nmax = 2)
# ├─ "juki"
# │  └─ Series
# │     ├─ Mean: n=15 | value=363.491
# │     └─ Extrema: n=15 | value=(min = 290.48, max = 743.74, nmin = 1, nmax = 1)
# ├─ "bernina"
# │  └─ Series
# │     ├─ Mean: n=146 | value=542.717
# │     └─ Extrema: n=146 | value=(min = 203.33, max = 2566.35, nmin = 13, nmax = 1)
# ├─ "pampers"
# │  └─ Series
# │     ├─ Mean: n=97 | value=7.71227
# │     └─ Extrema: n=97 | value=(min = 2.93, max = 22.0, nmin = 29, nmax = 7)
# ├─ "akom"
# │  └─ Series
# │     ├─ Mean: n=443 | value=73.8191
# │     └─ Extrema: n=443 | value=(min = 61.78, max = 110.68, nmin = 1, nmax = 5)
# ├─ "eurolux"
# │  └─ Series
# │     ├─ Mean: n=284 | value=84.6035
# │     └─ Extrema: n=284 | value=(min = 51.71, max = 220.57, nmin = 1, nmax = 1)
# ├─ "id-cooling"
# │  └─ Series
# │     ├─ Mean: n=48 | value=33.1183
# │     └─ Extrema: n=48 | value=(min = 3.6, max = 102.61, nmin = 1, nmax = 1)
# ├─ "blackberry"
# │  └─ Series
# │     ├─ Mean: n=26 | value=330.805
# │     └─ Extrema: n=26 | value=(min = 9.01, max = 411.59, nmin = 1, nmax = 20)
# ├─ "htc"
# │  └─ Series
# │     ├─ Mean: n=46 | value=136.244
# │     └─ Extrema: n=46 | value=(min = 102.94, max = 976.46, nmin = 44, nmax = 1)
# ├─ "rieker"
# │  └─ Series
# │     ├─ Mean: n=646 | value=93.692
# │     └─ Extrema: n=646 | value=(min = 28.83, max = 129.48, nmin = 2, nmax = 2)
# ├─ "selby"
# │  └─ Series
# │     ├─ Mean: n=172 | value=42.4598
# │     └─ Extrema: n=172 | value=(min = 36.01, max = 77.2, nmin = 64, nmax = 1)
# ├─ "intego"
# │  └─ Series
# │     ├─ Mean: n=35 | value=119.581
# │     └─ Extrema: n=35 | value=(min = 48.65, max = 154.44, nmin = 2, nmax = 19)
# ├─ "cnd"
# │  └─ Series
# │     ├─ Mean: n=10 | value=94.057
# │     └─ Extrema: n=10 | value=(min = 4.35, max = 257.38, nmin = 1, nmax = 2)
# ├─ "lux"
# │  └─ Series
# │     ├─ Mean: n=59 | value=119.749
# │     └─ Extrema: n=59 | value=(min = 39.9, max = 293.19, nmin = 7, nmax = 2)
# ├─ "versace"
# │  └─ Series
# │     ├─ Mean: n=876 | value=92.8676
# │     └─ Extrema: n=876 | value=(min = 38.35, max = 2436.1, nmin = 16, nmax = 1)
# ├─ "dxracer"
# │  └─ Series
# │     ├─ Mean: n=90 | value=288.146
# │     └─ Extrema: n=90 | value=(min = 218.77, max = 468.45, nmin = 5, nmax = 1)
# ├─ "bambola"
# │  └─ Series
# │     ├─ Mean: n=114 | value=48.4583
# │     └─ Extrema: n=114 | value=(min = 18.4, max = 119.95, nmin = 1, nmax = 2)
# ├─ "jabra"
# │  └─ Series
# │     ├─ Mean: n=44 | value=45.7909
# │     └─ Extrema: n=44 | value=(min = 14.15, max = 169.86, nmin = 1, nmax = 2)
# ├─ "ballu"
# │  └─ Series
# │     ├─ Mean: n=647 | value=47.0363
# │     └─ Extrema: n=647 | value=(min = 12.61, max = 437.33, nmin = 32, nmax = 1)
# ├─ "ivt"
# │  └─ Series
# │     ├─ Mean: n=27 | value=38.9737
# │     └─ Extrema: n=27 | value=(min = 14.0, max = 90.09, nmin = 2, nmax = 1)
# ├─ "wonlex"
# │  └─ Series
# │     ├─ Mean: n=354 | value=35.4395
# │     └─ Extrema: n=354 | value=(min = 15.42, max = 71.82, nmin = 2, nmax = 3)
# ├─ "huggies"
# │  └─ Series
# │     ├─ Mean: n=444 | value=12.5381
# │     └─ Extrema: n=444 | value=(min = 2.63, max = 27.03, nmin = 1, nmax = 11)
# ├─ "kitfort"
# │  └─ Series
# │     ├─ Mean: n=595 | value=109.852
# │     └─ Extrema: n=595 | value=(min = 16.86, max = 360.11, nmin = 3, nmax = 6)
# ├─ "lancome"
# │  └─ Series
# │     ├─ Mean: n=195 | value=73.8178
# │     └─ Extrema: n=195 | value=(min = 15.86, max = 151.87, nmin = 1, nmax = 2)
# ├─ "optima"
# │  └─ Series
# │     ├─ Mean: n=29 | value=98.9872
# │     └─ Extrema: n=29 | value=(min = 7.7, max = 295.99, nmin = 1, nmax = 4)
# ├─ "hiper"
# │  └─ Series
# │     ├─ Mean: n=10 | value=24.75
# │     └─ Extrema: n=10 | value=(min = 9.88, max = 86.51, nmin = 1, nmax = 1)
# ├─ "thermaltake"
# │  └─ Series
# │     ├─ Mean: n=100 | value=138.366
# │     └─ Extrema: n=100 | value=(min = 6.28, max = 486.47, nmin = 1, nmax = 1)
# ├─ "barneo"
# │  └─ Series
# │     ├─ Mean: n=60 | value=67.8328
# │     └─ Extrema: n=60 | value=(min = 36.04, max = 193.06, nmin = 7, nmax = 1)
# ├─ "mutant"
# │  └─ Series
# │     ├─ Mean: n=141 | value=44.9506
# │     └─ Extrema: n=141 | value=(min = 8.37, max = 78.51, nmin = 1, nmax = 1)
# ├─ "fassen"
# │  └─ Series
# │     ├─ Mean: n=418 | value=47.8378
# │     └─ Extrema: n=418 | value=(min = 33.98, max = 64.61, nmin = 1, nmax = 28)
# ├─ "trek"
# │  └─ Series
# │     ├─ Mean: n=7 | value=474.733
# │     └─ Extrema: n=7 | value=(min = 246.85, max = 1236.07, nmin = 1, nmax = 1)
# ├─ "titan"
# │  └─ Series
# │     ├─ Mean: n=39 | value=102.251
# │     └─ Extrema: n=39 | value=(min = 6.44, max = 262.56, nmin = 1, nmax = 1)
# ├─ "acme"
# │  └─ Series
# │     ├─ Mean: n=187 | value=43.9297
# │     └─ Extrema: n=187 | value=(min = 2.03, max = 146.7, nmin = 7, nmax = 3)
# ├─ "xinyu"
# │  └─ Series
# │     ├─ Mean: n=2 | value=8.98
# │     └─ Extrema: n=2 | value=(min = 8.98, max = 8.98, nmin = 2, nmax = 2)
# ├─ "imperial"
# │  └─ Series
# │     ├─ Mean: n=247 | value=501.721
# │     └─ Extrema: n=247 | value=(min = 32.92, max = 987.16, nmin = 2, nmax = 1)
# ├─ "toyota"
# │  └─ Series
# │     ├─ Mean: n=71 | value=188.037
# │     └─ Extrema: n=71 | value=(min = 11.58, max = 447.86, nmin = 1, nmax = 1)
# ├─ "hygge"
# │  └─ Series
# │     ├─ Mean: n=97 | value=639.884
# │     └─ Extrema: n=97 | value=(min = 574.02, max = 859.74, nmin = 73, nmax = 22)
# ├─ "dyson"
# │  └─ Series
# │     ├─ Mean: n=292 | value=586.72
# │     └─ Extrema: n=292 | value=(min = 307.83, max = 833.97, nmin = 3, nmax = 22)
# ├─ "zeppelin"
# │  └─ Series
# │     ├─ Mean: n=65 | value=141.526
# │     └─ Extrema: n=65 | value=(min = 6.67, max = 610.05, nmin = 1, nmax = 1)
# ├─ "acuvue"
# │  └─ Series
# │     ├─ Mean: n=27 | value=23.3026
# │     └─ Extrema: n=27 | value=(min = 21.88, max = 25.23, nmin = 4, nmax = 3)
# ├─ "nitto"
# │  └─ Series
# │     ├─ Mean: n=152 | value=79.2345
# │     └─ Extrema: n=152 | value=(min = 36.04, max = 167.31, nmin = 2, nmax = 1)
# ├─ "bovidix"
# │  └─ Series
# │     ├─ Mean: n=12 | value=43.7333
# │     └─ Extrema: n=12 | value=(min = 6.36, max = 86.23, nmin = 5, nmax = 4)
# ├─ "kurzweil"
# │  └─ Series
# │     ├─ Mean: n=108 | value=1002.66
# │     └─ Extrema: n=108 | value=(min = 283.15, max = 2191.56, nmin = 1, nmax = 10)
# ├─ "gross"
# │  └─ Series
# │     ├─ Mean: n=44 | value=129.182
# ...
# │     ├─ Mean: n=2 | value=74.5
# │     └─ Extrema: n=2 | value=(min = 54.98, max = 94.02, nmin = 1, nmax = 1)
# ├─ "dariush"
# │  └─ Series
# │     ├─ Mean: n=1 | value=92.67
# │     └─ Extrema: n=1 | value=(min = 92.67, max = 92.67, nmin = 1, nmax = 1)
# ├─ "grandvictory"
# │  └─ Series
# │     ├─ Mean: n=1 | value=37.34
# │     └─ Extrema: n=1 | value=(min = 37.34, max = 37.34, nmin = 1, nmax = 1)
# ├─ "harleybaby"
# │  └─ Series
# │     ├─ Mean: n=1 | value=267.45
# │     └─ Extrema: n=1 | value=(min = 267.45, max = 267.45, nmin = 1, nmax = 1)
# ├─ "terminus"
# │  └─ Series
# │     ├─ Mean: n=2 | value=121.815
# │     └─ Extrema: n=2 | value=(min = 94.91, max = 148.72, nmin = 1, nmax = 1)
# ├─ "merejbaspasy"
# │  └─ Series
# │     ├─ Mean: n=3 | value=11.58
# │     └─ Extrema: n=3 | value=(min = 11.58, max = 11.58, nmin = 3, nmax = 3)
# ├─ "tisa"
# │  └─ Series
# │     ├─ Mean: n=2 | value=20.85
# │     └─ Extrema: n=2 | value=(min = 10.81, max = 30.89, nmin = 1, nmax = 1)
# ├─ "norplast"
# │  └─ Series
# │     ├─ Mean: n=2 | value=32.18
# │     └─ Extrema: n=2 | value=(min = 32.18, max = 32.18, nmin = 2, nmax = 2)
# ├─ "vaiper"
# │  └─ Series
# │     ├─ Mean: n=1 | value=120.98
# │     └─ Extrema: n=1 | value=(min = 120.98, max = 120.98, nmin = 1, nmax = 1)
# ├─ "ewt"
# │  └─ Series
# │     ├─ Mean: n=1 | value=91.17
# │     └─ Extrema: n=1 | value=(min = 91.17, max = 91.17, nmin = 1, nmax = 1)
# ├─ "popov"
# │  └─ Series
# │     ├─ Mean: n=13 | value=114.938
# │     └─ Extrema: n=13 | value=(min = 86.23, max = 153.16, nmin = 5, nmax = 4)
# ├─ "houseofseasons"
# │  └─ Series
# │     ├─ Mean: n=17 | value=15.1353
# │     └─ Extrema: n=17 | value=(min = 5.12, max = 25.71, nmin = 1, nmax = 3)
# ├─ "crome"
# │  └─ Series
# │     ├─ Mean: n=1 | value=5.47
# │     └─ Extrema: n=1 | value=(min = 5.47, max = 5.47, nmin = 1, nmax = 1)
# ├─ "aorus"
# │  └─ Series
# │     ├─ Mean: n=1 | value=725.86
# │     └─ Extrema: n=1 | value=(min = 725.86, max = 725.86, nmin = 1, nmax = 1)
# ├─ "newbright"
# │  └─ Series
# │     ├─ Mean: n=1 | value=41.16
# │     └─ Extrema: n=1 | value=(min = 41.16, max = 41.16, nmin = 1, nmax = 1)
# ├─ "damper"
# │  └─ Series
# │     ├─ Mean: n=1 | value=38.61
# │     └─ Extrema: n=1 | value=(min = 38.61, max = 38.61, nmin = 1, nmax = 1)
# ├─ "teyko"
# │  └─ Series
# │     ├─ Mean: n=2 | value=52.77
# │     └─ Extrema: n=2 | value=(min = 43.76, max = 61.78, nmin = 1, nmax = 1)
# ├─ "theshinestonetrade"
# │  └─ Series
# │     ├─ Mean: n=3 | value=4.61
# │     └─ Extrema: n=3 | value=(min = 4.61, max = 4.61, nmin = 3, nmax = 3)
# ├─ "moose"
# │  └─ Series
# │     ├─ Mean: n=2 | value=9.895
# │     └─ Extrema: n=2 | value=(min = 8.98, max = 10.81, nmin = 1, nmax = 1)
# ├─ "meike"
# │  └─ Series
# │     ├─ Mean: n=1 | value=79.12
# │     └─ Extrema: n=1 | value=(min = 79.12, max = 79.12, nmin = 1, nmax = 1)
# ├─ "riche"
# │  └─ Series
# │     ├─ Mean: n=17 | value=28.1288
# │     └─ Extrema: n=17 | value=(min = 23.68, max = 34.49, nmin = 2, nmax = 1)
# ├─ "maxpro"
# │  └─ Series
# │     ├─ Mean: n=4 | value=406.7
# │     └─ Extrema: n=4 | value=(min = 406.7, max = 406.7, nmin = 4, nmax = 4)
# ├─ "rostok-mebel"
# │  └─ Series
# │     ├─ Mean: n=15 | value=142.01
# │     └─ Extrema: n=15 | value=(min = 133.77, max = 154.37, nmin = 8, nmax = 5)
# ├─ "petitfee"
# │  └─ Series
# │     ├─ Mean: n=3 | value=13.55
# │     └─ Extrema: n=3 | value=(min = 13.55, max = 13.55, nmin = 3, nmax = 3)
# ├─ "dvizenie"
# │  └─ Series
# │     ├─ Mean: n=4 | value=36.035
# │     └─ Extrema: n=4 | value=(min = 32.43, max = 39.64, nmin = 2, nmax = 2)
# ├─ "blaster"
# │  └─ Series
# │     ├─ Mean: n=1 | value=30.86
# │     └─ Extrema: n=1 | value=(min = 30.86, max = 30.86, nmin = 1, nmax = 1)
# ├─ "buttonblue"
# │  └─ Series
# │     ├─ Mean: n=2 | value=4.36
# │     └─ Extrema: n=2 | value=(min = 3.66, max = 5.06, nmin = 1, nmax = 1)
# ├─ "eltex"
# │  └─ Series
# │     ├─ Mean: n=2 | value=67.44
# │     └─ Extrema: n=2 | value=(min = 67.44, max = 67.44, nmin = 2, nmax = 2)
# ├─ "aquatic"
# │  └─ Series
# │     ├─ Mean: n=2 | value=13.77
# │     └─ Extrema: n=2 | value=(min = 12.48, max = 15.06, nmin = 1, nmax = 1)
# ├─ "popurri"
# │  └─ Series
# │     ├─ Mean: n=7 | value=10.5557
# │     └─ Extrema: n=7 | value=(min = 5.71, max = 22.64, nmin = 3, nmax = 1)
# ├─ "aksion"
# │  └─ Series
# │     ├─ Mean: n=1 | value=74.65
# │     └─ Extrema: n=1 | value=(min = 74.65, max = 74.65, nmin = 1, nmax = 1)
# ├─ "triumf"
# │  └─ Series
# │     ├─ Mean: n=3 | value=194.407
# │     └─ Extrema: n=3 | value=(min = 158.54, max = 226.5, nmin = 1, nmax = 1)
# ├─ "realflame"
# │  └─ Series
# │     ├─ Mean: n=1 | value=488.82
# │     └─ Extrema: n=1 | value=(min = 488.82, max = 488.82, nmin = 1, nmax = 1)
# ├─ "luazonlighting"
# │  └─ Series
# │     ├─ Mean: n=1 | value=18.6
# │     └─ Extrema: n=1 | value=(min = 18.6, max = 18.6, nmin = 1, nmax = 1)
# ├─ "batik"
# │  └─ Series
# │     ├─ Mean: n=6 | value=5.38
# │     └─ Extrema: n=6 | value=(min = 4.35, max = 7.7, nmin = 2, nmax = 1)
# ├─ "erichkrause"
# │  └─ Series
# │     ├─ Mean: n=3 | value=9.93
# │     └─ Extrema: n=3 | value=(min = 8.73, max = 11.56, nmin = 1, nmax = 1)
# ├─ "zing"
# │  └─ Series
# │     ├─ Mean: n=1 | value=16.89
# │     └─ Extrema: n=1 | value=(min = 16.89, max = 16.89, nmin = 1, nmax = 1)
# ├─ "hightechway"
# │  └─ Series
# │     ├─ Mean: n=2 | value=164.75
# │     └─ Extrema: n=2 | value=(min = 155.06, max = 174.44, nmin = 1, nmax = 1)
# ├─ "cocoonababy"
# │  └─ Series
# │     ├─ Mean: n=1 | value=168.6
# │     └─ Extrema: n=1 | value=(min = 168.6, max = 168.6, nmin = 1, nmax = 1)
# ├─ "marcher"
# │  └─ Series
# │     ├─ Mean: n=1 | value=45.48
# │     └─ Extrema: n=1 | value=(min = 45.48, max = 45.48, nmin = 1, nmax = 1)
# ├─ "kaemingkbv"
# │  └─ Series
# │     ├─ Mean: n=4 | value=76.465
# │     └─ Extrema: n=4 | value=(min = 55.5, max = 87.96, nmin = 1, nmax = 2)
# ├─ "provence"
# │  └─ Series
# │     ├─ Mean: n=1 | value=4.86
# │     └─ Extrema: n=1 | value=(min = 4.86, max = 4.86, nmin = 1, nmax = 1)
# ├─ "indiana"
# │  └─ Series
# │     ├─ Mean: n=1 | value=50.45
# │     └─ Extrema: n=1 | value=(min = 50.45, max = 50.45, nmin = 1, nmax = 1)
# ├─ "belkin"
# │  └─ Series
# │     ├─ Mean: n=1 | value=17.99
# │     └─ Extrema: n=1 | value=(min = 17.99, max = 17.99, nmin = 1, nmax = 1)
# ├─ "dolcevita"
# │  └─ Series
# │     ├─ Mean: n=2 | value=174.26
# │     └─ Extrema: n=2 | value=(min = 174.26, max = 174.26, nmin = 2, nmax = 2)
# ├─ "naturalist"
# │  └─ Series
# │     ├─ Mean: n=2 | value=1.8
# │     └─ Extrema: n=2 | value=(min = 1.8, max = 1.8, nmin = 2, nmax = 2)
# ├─ "wiseson"
# │  └─ Series
# │     ├─ Mean: n=1 | value=61.01
# │     └─ Extrema: n=1 | value=(min = 61.01, max = 61.01, nmin = 1, nmax = 1)
# ├─ "startradingab"
# │  └─ Series
# │     ├─ Mean: n=1 | value=702.72
# │     └─ Extrema: n=1 | value=(min = 702.72, max = 702.72, nmin = 1, nmax = 1)
# ├─ "leven"
# │  └─ Series
# │     ├─ Mean: n=1 | value=13.26
# │     └─ Extrema: n=1 | value=(min = 13.26, max = 13.26, nmin = 1, nmax = 1)
# ├─ "skazocnyjpatrul"
# │  └─ Series
# │     ├─ Mean: n=1 | value=19.19
# │     └─ Extrema: n=1 | value=(min = 19.19, max = 19.19, nmin = 1, nmax = 1)
# ├─ "poppops"
# │  └─ Series
# │     ├─ Mean: n=1 | value=11.04
# │     └─ Extrema: n=1 | value=(min = 11.04, max = 11.04, nmin = 1, nmax = 1)
# ├─ "k-star"
# │  └─ Series
# │     ├─ Mean: n=2 | value=900.92
# │     └─ Extrema: n=2 | value=(min = 900.92, max = 900.92, nmin = 2, nmax = 2)
# ├─ "cressi"
# │  └─ Series
# │     ├─ Mean: n=1 | value=40.93
# │     └─ Extrema: n=1 | value=(min = 40.93, max = 40.93, nmin = 1, nmax = 1)
# ├─ "mecta"
# │  └─ Series
# │     ├─ Mean: n=2 | value=43.76
# │     └─ Extrema: n=2 | value=(min = 43.76, max = 43.76, nmin = 2, nmax = 2)
# ├─ "hohner"
# │  └─ Series
# │     ├─ Mean: n=1 | value=107.08
# │     └─ Extrema: n=1 | value=(min = 107.08, max = 107.08, nmin = 1, nmax = 1)
# ├─ "cardrox"
# │  └─ Series
# │     ├─ Mean: n=1 | value=299.98
# │     └─ Extrema: n=1 | value=(min = 299.98, max = 299.98, nmin = 1, nmax = 1)
# ├─ "canwood"
# │  └─ Series
# │     ├─ Mean: n=1 | value=51.48
# │     └─ Extrema: n=1 | value=(min = 51.48, max = 51.48, nmin = 1, nmax = 1)
# ├─ "orivel"
# │  └─ Series
# │     ├─ Mean: n=1 | value=141.66
# │     └─ Extrema: n=1 | value=(min = 141.66, max = 141.66, nmin = 1, nmax = 1)
# ├─ "temp"
# │  └─ Series
# │     ├─ Mean: n=1 | value=92.72
# │     └─ Extrema: n=1 | value=(min = 92.72, max = 92.72, nmin = 1, nmax = 1)
# ├─ "maja"
# │  └─ Series
# │     ├─ Mean: n=1 | value=58.17
# │     └─ Extrema: n=1 | value=(min = 58.17, max = 58.17, nmin = 1, nmax = 1)
# ├─ "eneos"
# │  └─ Series
# │     ├─ Mean: n=2 | value=23.94
# │     └─ Extrema: n=2 | value=(min = 23.94, max = 23.94, nmin = 2, nmax = 2)
# ├─ "soyntec"
# │  └─ Series
# │     ├─ Mean: n=1 | value=2.55
# │     └─ Extrema: n=1 | value=(min = 2.55, max = 2.55, nmin = 1, nmax = 1)
# ├─ "klorane"
# │  └─ Series
# │     ├─ Mean: n=2 | value=5.125
# │     └─ Extrema: n=2 | value=(min = 1.24, max = 9.01, nmin = 1, nmax = 1)
# ├─ "santacruz"
# │  └─ Series
# │     ├─ Mean: n=1 | value=282.89
# │     └─ Extrema: n=1 | value=(min = 282.89, max = 282.89, nmin = 1, nmax = 1)
# ├─ "bayerlux"
# │  └─ Series
# │     ├─ Mean: n=1 | value=41.16
# │     └─ Extrema: n=1 | value=(min = 41.16, max = 41.16, nmin = 1, nmax = 1)
# ├─ "pixiebelles"
# │  └─ Series
# │     ├─ Mean: n=1 | value=42.99
# │     └─ Extrema: n=1 | value=(min = 42.99, max = 42.99, nmin = 1, nmax = 1)
# ├─ "cameo"
# │  └─ Series
# │     ├─ Mean: n=1 | value=256.62
# │     └─ Extrema: n=1 | value=(min = 256.62, max = 256.62, nmin = 1, nmax = 1)
# ├─ "sweetyhome"
# │  └─ Series
# │     ├─ Mean: n=1 | value=15.42
# │     └─ Extrema: n=1 | value=(min = 15.42, max = 15.42, nmin = 1, nmax = 1)
# ├─ "paiste"
# │  └─ Series
# │     ├─ Mean: n=1 | value=141.57
# │     └─ Extrema: n=1 | value=(min = 141.57, max = 141.57, nmin = 1, nmax = 1)
# ├─ "shoesrepublic"
# │  └─ Series
# │     ├─ Mean: n=1 | value=69.5
# │     └─ Extrema: n=1 | value=(min = 69.5, max = 69.5, nmin = 1, nmax = 1)
# ├─ "dfz"
# │  └─ Series
# │     ├─ Mean: n=1 | value=0.9
# │     └─ Extrema: n=1 | value=(min = 0.9, max = 0.9, nmin = 1, nmax = 1)
# ├─ "sun"
# │  └─ Series
# │     ├─ Mean: n=4 | value=48.91
# │     └─ Extrema: n=4 | value=(min = 48.91, max = 48.91, nmin = 4, nmax = 4)
# ├─ "strong"
# │  └─ Series
# │     ├─ Mean: n=6 | value=113.26
# │     └─ Extrema: n=6 | value=(min = 113.26, max = 113.26, nmin = 6, nmax = 6)
# ├─ "dinamical"
# │  └─ Series
# │     ├─ Mean: n=3 | value=46.31
# │     └─ Extrema: n=3 | value=(min = 46.31, max = 46.31, nmin = 3, nmax = 3)
# ├─ "sunday"
# │  └─ Series
# │     ├─ Mean: n=2 | value=267.7
# │     └─ Extrema: n=2 | value=(min = 267.7, max = 267.7, nmin = 2, nmax = 2)
# ├─ "mydean"
# │  └─ Series
# │     ├─ Mean: n=1 | value=154.44
# │     └─ Extrema: n=1 | value=(min = 154.44, max = 154.44, nmin = 1, nmax = 1)
# ├─ "absolutechampion"
# │  └─ Series
# │     ├─ Mean: n=1 | value=166.03
# │     └─ Extrema: n=1 | value=(min = 166.03, max = 166.03, nmin = 1, nmax = 1)
# ├─ "saeshin"
# │  └─ Series
# │     ├─ Mean: n=3 | value=123.56
# │     └─ Extrema: n=3 | value=(min = 123.56, max = 123.56, nmin = 3, nmax = 3)
# ├─ "zvezda"
# │  └─ Series
# │     ├─ Mean: n=1 | value=11.97
# │     └─ Extrema: n=1 | value=(min = 11.97, max = 11.97, nmin = 1, nmax = 1)
# ├─ "rovigo"
# │  └─ Series
# │     ├─ Mean: n=5 | value=113.26
# │     └─ Extrema: n=5 | value=(min = 108.11, max = 118.41, nmin = 1, nmax = 1)
# ├─ "screecherswild"
# │  └─ Series
# │     ├─ Mean: n=1 | value=24.43
# │     └─ Extrema: n=1 | value=(min = 24.43, max = 24.43, nmin = 1, nmax = 1)
# ├─ "mif"
# │  └─ Series
# │     ├─ Mean: n=4 | value=245.18
# │     └─ Extrema: n=4 | value=(min = 202.58, max = 372.98, nmin = 3, nmax = 1)
# ├─ "budibasa"
# │  └─ Series
# │     ├─ Mean: n=1 | value=12.41
# │     └─ Extrema: n=1 | value=(min = 12.41, max = 12.41, nmin = 1, nmax = 1)
# ├─ "sharp"
# │  └─ Series
# │     ├─ Mean: n=1 | value=411.83
# │     └─ Extrema: n=1 | value=(min = 411.83, max = 411.83, nmin = 1, nmax = 1)
# ├─ "zanry"
# │  └─ Series
# │     ├─ Mean: n=1 | value=7.36
# │     └─ Extrema: n=1 | value=(min = 7.36, max = 7.36, nmin = 1, nmax = 1)
# ├─ "romer"
# │  └─ Series
# │     ├─ Mean: n=1 | value=145.43
# │     └─ Extrema: n=1 | value=(min = 145.43, max = 145.43, nmin = 1, nmax = 1)
# ├─ "vmv"
# │  └─ Series
# │     ├─ Mean: n=1 | value=56.6
# │     └─ Extrema: n=1 | value=(min = 56.6, max = 56.6, nmin = 1, nmax = 1)
# ├─ "elektrostandard"
# │  └─ Series
# │     ├─ Mean: n=2 | value=58.17
# │     └─ Extrema: n=2 | value=(min = 58.17, max = 58.17, nmin = 2, nmax = 2)
# ├─ "kaemingk"
# │  └─ Series
# │     ├─ Mean: n=1 | value=608.66
# │     └─ Extrema: n=1 | value=(min = 608.66, max = 608.66, nmin = 1, nmax = 1)
# ├─ "piter-trejd"
# │  └─ Series
# │     ├─ Mean: n=1 | value=7.61
# │     └─ Extrema: n=1 | value=(min = 7.61, max = 7.61, nmin = 1, nmax = 1)
# ├─ "rosmen"
# │  └─ Series
# │     ├─ Mean: n=1 | value=12.12
# │     └─ Extrema: n=1 | value=(min = 12.12, max = 12.12, nmin = 1, nmax = 1)
# ├─ "steffilove"
# │  └─ Series
# │     ├─ Mean: n=1 | value=45.79
# │     └─ Extrema: n=1 | value=(min = 45.79, max = 45.79, nmin = 1, nmax = 1)
# ├─ "kuppersbusch"
# │  └─ Series
# │     ├─ Mean: n=1 | value=1408.02
# │     └─ Extrema: n=1 | value=(min = 1408.02, max = 1408.02, nmin = 1, nmax = 1)
# ├─ "evgo"
# │  └─ Series
# │     ├─ Mean: n=1 | value=106.8
# │     └─ Extrema: n=1 | value=(min = 106.8, max = 106.8, nmin = 1, nmax = 1)
# ├─ "secretgourmet"
# │  └─ Series
# │     ├─ Mean: n=1 | value=35.08
# │     └─ Extrema: n=1 | value=(min = 35.08, max = 35.08, nmin = 1, nmax = 1)
# ├─ "liebherr"
# │  └─ Series
# │     ├─ Mean: n=1 | value=352.11
# │     └─ Extrema: n=1 | value=(min = 352.11, max = 352.11, nmin = 1, nmax = 1)
# ├─ "elvin"
# │  └─ Series
# │     ├─ Mean: n=1 | value=69.24
# │     └─ Extrema: n=1 | value=(min = 69.24, max = 69.24, nmin = 1, nmax = 1)
# ├─ "siberia"
# │  └─ Series
# │     ├─ Mean: n=2 | value=380.83
# │     └─ Extrema: n=2 | value=(min = 380.83, max = 380.83, nmin = 2, nmax = 2)
# ├─ "dragonfly"
# │  └─ Series
# │     ├─ Mean: n=1 | value=89.32
# │     └─ Extrema: n=1 | value=(min = 89.32, max = 89.32, nmin = 1, nmax = 1)
# ├─ "dunu"
# │  └─ Series
# │     ├─ Mean: n=3 | value=43.5
# │     └─ Extrema: n=3 | value=(min = 43.5, max = 43.5, nmin = 3, nmax = 3)
# ├─ "husky"
# │  └─ Series
# │     ├─ Mean: n=1 | value=247.11
# │     └─ Extrema: n=1 | value=(min = 247.11, max = 247.11, nmin = 1, nmax = 1)
# ├─ "kursiv"
# │  └─ Series
# │     ├─ Mean: n=1 | value=9.01
# │     └─ Extrema: n=1 | value=(min = 9.01, max = 9.01, nmin = 1, nmax = 1)
# ├─ "htl"
# │  └─ Series
# │     ├─ Mean: n=1 | value=360.37
# │     └─ Extrema: n=1 | value=(min = 360.37, max = 360.37, nmin = 1, nmax = 1)
# ├─ "denso"
# │  └─ Series
# │     ├─ Mean: n=1 | value=10.04
# │     └─ Extrema: n=1 | value=(min = 10.04, max = 10.04, nmin = 1, nmax = 1)
# ├─ "synology"
# │  └─ Series
# │     ├─ Mean: n=1 | value=355.99
# │     └─ Extrema: n=1 | value=(min = 355.99, max = 355.99, nmin = 1, nmax = 1)
# ├─ "annaite"
# │  └─ Series
# │     ├─ Mean: n=1 | value=48.84
# │     └─ Extrema: n=1 | value=(min = 48.84, max = 48.84, nmin = 1, nmax = 1)
# ├─ "info"
# │  └─ Series
# │     ├─ Mean: n=2 | value=233.98
# │     └─ Extrema: n=2 | value=(min = 233.98, max = 233.98, nmin = 2, nmax = 2)
# ├─ "glanzen"
# │  └─ Series
# │     ├─ Mean: n=1 | value=4.09
# │     └─ Extrema: n=1 | value=(min = 4.09, max = 4.09, nmin = 1, nmax = 1)
# ├─ "family"
# │  └─ Series
# │     ├─ Mean: n=1 | value=1055.34
# │     └─ Extrema: n=1 | value=(min = 1055.34, max = 1055.34, nmin = 1, nmax = 1)
# ├─ "lamel"
# │  └─ Series
# │     ├─ Mean: n=1 | value=5.68
# │     └─ Extrema: n=1 | value=(min = 5.68, max = 5.68, nmin = 1, nmax = 1)
# ├─ "duo"
# │  └─ Series
# │     ├─ Mean: n=1 | value=17.56
# │     └─ Extrema: n=1 | value=(min = 17.56, max = 17.56, nmin = 1, nmax = 1)
# ├─ "westone"
# │  └─ Series
# │     ├─ Mean: n=2 | value=186.37
# │     └─ Extrema: n=2 | value=(min = 186.37, max = 186.37, nmin = 2, nmax = 2)
# ├─ "qplay"
# │  └─ Series
# │     ├─ Mean: n=1 | value=144.15
# │     └─ Extrema: n=1 | value=(min = 144.15, max = 144.15, nmin = 1, nmax = 1)
# ├─ "triumph"
# │  └─ Series
# │     ├─ Mean: n=1 | value=4.37
# │     └─ Extrema: n=1 | value=(min = 4.37, max = 4.37, nmin = 1, nmax = 1)
# ├─ "prajm-evroznak"
# │  └─ Series
# │     ├─ Mean: n=1 | value=9.86
# │     └─ Extrema: n=1 | value=(min = 9.86, max = 9.86, nmin = 1, nmax = 1)
# ├─ "targus"
# │  └─ Series
# │     ├─ Mean: n=1 | value=42.76
# │     └─ Extrema: n=1 | value=(min = 42.76, max = 42.76, nmin = 1, nmax = 1)
# └─ "valberg"
#    └─ Series
#       ├─ Mean: n=1 | value=20.49
#       └─ Extrema: n=1 | value=(min = 20.49, max = 20.49, nmin = 1, nmax = 1)

# %%
mean(purchases.price[purchases.brand .== "xiaomi"])

# %% [markdown]
# # Как все это можно развивать
#
# ## Типы данных
#     * массивы
#     * CategiricalArrays
#     * NamedTuple
#
# ## Аггрегация
#     Тут много всего, от простой аггрегации в памяти, до аггрегации с использованием временных файлов и предварительно вычисленных индексов
#
# ## Индексы
#     * Классические индексы малополезны, но можно, например, хранить Bloom фильтр для каждого блока - это должно хорошо ускорить фильтрацию
#
# ## Join
#     * Довольно тяжелы в реализации, тем не менее вполне реальны
#
# ## Всякие разности
#     * Пересортировка таблиц на диске без поднятия их полностью в память
#     * Вставка в произвольную позицию / изменение записей
#     * Всякие "индексы" для групировок/джойнов, возможно автоматические. Т.е. индекс создается с каким-то TTL при джойне
#
# ## Инфраструктура
#     * Сущность "База данных"
#     * Фоновые процессы - всякий дорасчет индексов, предагреггации и т.д.
#     * Сетевой интерфейс
#     * Шардинг, распределенные вычисления и т.д.
#
# # Главный вопрос - а надо ли? )
